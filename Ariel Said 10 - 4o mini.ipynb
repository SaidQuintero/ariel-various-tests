# %%
import os
import json
import re
from datetime import datetime
import hashlib

from langchain_openai import AzureOpenAIEmbeddings
from openai import OpenAI
from azure.core.credentials import AzureKeyCredential
from azure.search.documents import SearchClient
from azure.search.documents.models import QueryType
from azure.search.documents._generated.models import QueryCaptionResult

from openai import AzureOpenAI
import tiktoken
from langsmith import traceable
from langsmith.wrappers import wrap_openai
from dotenv import load_dotenv

load_dotenv()

def num_tokens_from_string(string: str, encoding_name: str = "cl100k_base") -> int:
    """Returns the number of tokens in a text string."""
    encoding = tiktoken.get_encoding(encoding_name)
    num_tokens = len(encoding.encode(string))
    return num_tokens

class AzureEmbeddings:

    def __init__(self):
        pass

    @staticmethod
    def get_embedding():
        return AzureOpenAIEmbeddings(
            azure_deployment=os.getenv("AZURE_OPENAI_DEPLOYMENT"), 
            openai_api_version="2023-08-01-preview",
            openai_api_key=os.getenv("AZURE_OPENAI_API_KEY"),
            azure_endpoint=os.getenv("AZURE_OPENAI_URL")
        )

    @staticmethod
    def generate_embeddings(content: str):
        embeddings = AzureOpenAIEmbeddings(
            azure_deployment=os.getenv("AZURE_OPENAI_DEPLOYMENT"), 
            openai_api_version="2023-08-01-preview",
            openai_api_key=os.getenv("AZURE_OPENAI_API_KEY"),
            azure_endpoint=os.getenv("AZURE_OPENAI_URL")
        )

        doc_result = embeddings.embed_documents([content])

        return doc_result[0]

# openai_client = AzureOpenAI(
#     api_key=os.getenv("AZURE_CHAT_OPENAI_API_KEY"), 
#     api_version=os.getenv("AZURE_CHAT_OPENAI_API_VERSION"), 
#     azure_endpoint=os.getenv("AZURE_CHAT_OPENAI_ENDPOINT")
#     )
openai_client = wrap_openai(OpenAI(
    api_key=os.getenv("OPENAI_API_KEY")
    ))

embeddings_client = AzureEmbeddings()
store_search_url: str = f'https://{os.getenv('AZURE_COGNITIVE_SEARCH_SERVICE_NAME')}.search.windows.net'
search_client = SearchClient(
            store_search_url, os.getenv("AZURE_COGNITIVE_SEARCH_INDEX_NAME"),
            AzureKeyCredential(os.getenv("AZURE_COGNITIVE_SEARCH_API_KEY"))
        )

# %%
log_file_name = ""


def ensure_directory(directory_name):
    if not os.path.exists(directory_name):
        os.makedirs(directory_name)


def log(message):
    global log_file_name
    ensure_directory("logs")
    with open(log_file_name, "a") as file:
        file.write(f"{datetime.now()}\n{message}\n")

# %%
conversation_price = 0
conversation_ct = 0
conversation_pt = 0
conversation_tt = 0


def get_conversation_price(new_completion, model="gpt4o"):
    global conversation_price, conversation_ct, conversation_pt, conversation_tt
    USD_price_in_COP = 4100

    if model == "gpt4o-mini":
        in_price = 0.00000015
        out_price = 0.0000006
    if model == "gpt-4o-2024-08-06":
        in_price = 0.0000025
        out_price = 0.000010
    if model == "gpt4o":
        in_price = 0.000005
        out_price = 0.000015
    if model == "llama-3-8b":
        in_price = 0.00000005
        out_price = 0.00000008
    if model == "llama-3-70b":
        in_price = 0.00000059
        out_price = 0.0000007
    if model == "haiku":
        in_price = 0.00000025
        out_price = 0.00000125

    ct = new_completion.usage.completion_tokens
    pt = new_completion.usage.prompt_tokens
    usd_total_price = (ct * out_price) + (pt * in_price)
    cop_total_price = usd_total_price * USD_price_in_COP
    conversation_price += cop_total_price
    print(
        f"💰 Conversation price: ${conversation_price} COP\n"
        f"   This message: ${cop_total_price} COP "
        f""
    )
    log(
        f"💰 Conversation price: ${conversation_price} COP\n"
        f"   This message: ${cop_total_price} COP "
        f""
    )

    return

# %%
### 🔑 Definir system prompt y tools

messages = []
conversation = []
user_input = ""

codes_to_laws = """
- Código Penal: Ley 599 de 2000
- Código Civil: Ley 57 de 1887
- Código de Comercio: Decreto 410 de 1971
- Código de Procedimiento Civil: Decreto 1400 de 1970
- Código de Procedimiento Penal: Ley 906 de 2004
- Código General del Proceso: Ley 1564 de 2012
- Código de la Infancia y la Adolescencia: Ley 1098 de 2006
- Código Nacional de Policía: Ley 1801 de 2016
- Código de Recursos Naturales: Decreto 2811 de 1974
- Código Electoral: Decreto 2241 de 1986
- Código Disciplinario Único: Ley 734 de 2002
- Código Contencioso Administrativo: Ley 1437 de 2011 (anteriormente Decreto 1 de 1984)
- Código de Minas: Ley 685 de 2001
- Código de Educación: Ley 115 de 1994
- Código Nacional de Tránsito Terrestre: Ley 769 de 2002
- Código de Construcción del Distrito Capital de Bogotá: Acuerdo 20 de 1995
- Código de Construcción Sismo-Resistente: NSR-10 
- Código de Régimen Departamental: Decreto 1222 de 1986
- Código de Régimen Político y Municipal: Decreto-Ley 1333 de 1986
- Código Penal Militar: Ley 1407 de 2010
- Código Penitenciario y Carcelario: Ley 65 de 1993
- Código Procesal del Trabajo y del Seguro Social: Decreto-Ley 2158 de 1948
- Código Sustantivo del Trabajo: Decreto 2663 de 1950
- Código Sanitario Nacional: Ley 9 de 1979
- Código General Disciplinario: Ley 1952 de 2019
- Código Nacional de Seguridad y Convivencia Ciudadana: Ley 1801 de 2016
- Código Penal Militar: Ley 522 de 1999 """


get_next_chunk = {
    "type": "function",
    "function": {
        "name": "get_next_chunk",
        "description": "Use this tool to get when an important sources comes incomplete or the content is cut off. This tool will help you retrieve the following section of that given source.",
        "parameters": {
            "type": "object",
            "properties": {
                "source_id": {
                    "type": "string",
                    "description": "the unique identifier of the chunk that is incomplete. eg:'20240719192458csjscpboletinjurisprudencial20181219pdf_chunk30'",
                },
            },
            "required": ["source_id"],
        },
    },
}

response_system_template = f"""
Eres Ariel, un asistente de investigación legal en derecho colombiano. Sigue estas instrucciones al responder: 
  
1. Consulta de Fuentes: 
- Tienes acceso a algunas fuentes que previamente has encontrado y seleccionado para generar esta respuesta. Dentro de esas fuentes se encuentra toda la información disponible para responder.  
- Expresa toda la información que encuentres en las fuentes proporcionadas y que sea relevante para responder. 
- Si las fuentes no ayudan a responder la pregunta, responde: "No encuentro información con esos términos, ¿puedes reformular tu consulta?" 
- Las fuentes vienen en fragmentos del documento completo con los siguientes campos: 
    - id: Identificador único del fragmento 
    - title: Título del documento 
    - author: Autor del documento 
    - keywords: Tema legal, (puede ser: General, Constitucional, Internacional_Publico, Internacional_Privado, Penal, Financiero, entre otros). 
    - category: Tipo de documento legal. (Las opciones son: Jurisprudencia, Doctrina, Constitucional, Legal, Infralegal y Otros_temas_legales).  
    - page: Página de la que fue extraído el fragmento. 
    - year: Año en el que se publicó el documento. 
    - content: 500 tokens de contenido, fragmento o extracto del documento. Son solo 500 tokens del documento completo. 

2. Redacción de Respuestas:
- Sé detallado y preciso, utilizando exclusivamente la información de las fuentes proporcionadas.
- No incluyas información que no haya sido extraída directamente de las fuentes. Está prohibido.
- No inventes información por ningún motivo. No alucines.

3. Citación de Fuentes:
- Cita el mayor número de fuentes aplicables.
- Utiliza corchetes para referenciar la fuente con el ID del fragmento sin modificarlo, por ejemplo: [12345_id_de_ejemplo].
- No combines fuentes; enlista cada fuente por separado.

3. Formato de Respuesta:
- Escribe tus respuestas en formato HTML, sin incluir los tags "```html" al principio o al final.
- Utiliza etiquetas HTML estándar como <p>, <strong>, <em>, etc.

5. Interpretación de Categorías:
- Prioriza las fuentes según su categoría:
    1. Constitucional: Es la norma máxima y más importante del país.  
    2. Legal: Es la que le sigue en importancia y son las leyes dictadas por el Congreso.  
    3. Infralegal: Le sigue en importancia a la categoría Legal y comprende decretos, resoluciones y otros documentos oficiales de autoridades públicas como ministerios y superintendencias.  
    4. Jurisprudencia: Están por debajo de las leyes y las normas infralegales, sirven como criterio auxiliar para interpretar las normas y desarrollar su contenido. Son proferidas por jueces de la república y demuestran cómo se ha ejercido la ley en el pasado. Las sentencias y autos de la Corte Constitucional son las más importantes y están al mismo nivel de la Constitución Política, ya que son la interpretación oficial de esta. Las sentencias y autos de las Altas Cortes (Corte Constitucional, Corte Suprema de Justicia, Consejo de Estado, Consejo Superior de la Judicatura y JEP) están por encima de las de los Tribunales Superiores.
    5. Doctrina: Son documentos o libros escritos por autores del derecho que no son parte de la ley pero ayudan a darle una interpretación a la ley o al resto de fuentes. 
- Da mayor importancia a las fuentes más actuales.

6. Precisión Legal:
- Siempre dale más importancia a la fuente primaria. Si debes citar una ley, artículo o norma, cita la fuente directa, es decir, esa ley, artículo o normal.
- Las fuentes secundarias te ayudarán a entender la interpretación sobre las fuentes primarias.
- No confundas leyes o artículos; si el usuario pregunta por una ley o sentencia específica, ignora extractos de otras leyes, sentencias u otras fuentes.
- Utiliza las fuentes para dar una respuesta completa y darle al usuario información adicional que pueda serle de ayuda.
- Cita textualmente cuando necesites mencionar el contenido un artículo, ley u otro documento y si el tamaño de este lo permite.
- Si el usuario no aporta toda la información relevante, puedes solicitarle  mayor información adicional para entender mejor el contexto de la pregunta y darle una respuesta más acertada. 

7. Evita Imprecisiones:
- En caso de encontrar información contradictoria, señálala y sugiere una posible causa.
- No te salgas del tema de la pregunta del usuario.
- En caso que el usuario haya dado información incorrecto o imprecisa, señálala y da un argumento.
- Si la ley, la jurisprudencia y la doctrina tienen respuestas diferentes o interpretaciones diferentes para la misma pregunta, señala las distintas perspectivas.
"""

selection_system_prompt = f"""
Eres un asistente de investigación legal en derecho colombiano y tienes la tarea de seleccionar la mejor información dentro de un listado de fragmentos de documentos legales, para luego dárselos a un abogado y que este genere una respuesta al usuario con la información que seleccionaste.
Estos fragmentos son resultado de una búsqueda que acabas de realizar y los encontrarás con la siguiente estructura:
- id: Identificador único del fragmento.
- title: Título del documento.
- author: Autor del documento.
- keywords: Tema legal, puede ser: General, Constitucional, Internacional_Publico, Internacional_Privado, Penal, Financiero, entre otros.
- category: Tipo de documento legal. Las opciones son: Jurisprudencia, Doctrina, Constitucional, Legal, Infralegal y Otros_temas_legales. 
- page: Página de la que fue extraído el fragmento.
- year: Año en el que se publicó el documento.
- content: 500 tokens de contenido, fragmento, chunk o extracto del documento. Son solo 500 tokens del documento completo.


Para seleccionar los fragmentos correctos en tu selección debes seguir los siguiente pasos:

1. Identifica Información Relevante:
- Revisa todos los fragmentos e identifica aquellos que tengan la mejor información para responder a las pregunta del usuario.
- Son relevantes aquellos fragmentos que mencionen el artículo, ley, documento, teoría que el usuario necesita.
- Prioriza las fuentes primarias, por encima de las fuentes secundarias de información.
- No confundas leyes o artículos; si el usuario pregunta por una ley o sentencia específica, ignora extractos de otras leyes, sentencias u otras fuentes, a menos que sean relevantes para su pregunta.
- Da mayor importancia a los fragmentos más actuales, a menos que el usuario diga lo contrario.
- Prioriza los fragmentos según su categoría:
    1. Constitucional: Es la norma máxima y más importante del país.  
    2. Legal: Es la que le sigue en importancia y son las leyes dictadas por el Congreso.  
    3. Infralegal: Le sigue en importancia a la categoría Legal y comprende decretos, resoluciones y otros documentos oficiales de autoridades públicas como ministerios y superintendencias.  
    4. Jurisprudencia: Están por debajo de las leyes y las normas infralegales, sirven como criterio auxiliar para interpretar las normas y desarrollar su contenido. Son proferidas por jueces de la república y demuestran cómo se ha ejercido la ley en el pasado. Las sentencias y autos de la Corte Constitucional son las más importantes y están al mismo nivel de la Constitución Política. Las sentencias y autos de las Altas Cortes (Corte Constitucional, Corte Suprema de Justicia, Consejo de Estado, Consejo Superior de la Judicatura y JEP) están por encima de las de los Tribunales Superiores.
    5. Doctrina: Son documentos o libros escritos por autores del derecho que no son parte de la ley pero ayudan a darle una interpretación a la ley o al resto de fuentes. 
- Da mayor importancia a los fragmentos más actuales, a menos que el usuario diga lo contrario.
- Dale más importancia a los fragmentos que contienen extractos textuales del documento que el usuario pidió.

2. Crear Una Estrategia de Selección:
- Selecciona un grupo de fuentes donde puedas dar una respuesta completa a la pregunta con diversor agumentos. 
- En algunas ocasiones habrá información contradictoria entre los fragmentos que puede ser relevante incluir. En ese caso, incluye los diversor puntos de vista y la información contradictoria.
- No selecciones fuentes repetitivas, busca tener diversidad en tus fuentes.
- Las fuentes secundarias, la doctrina y jurisprudencia te ayudarán a entender la interpretación sobre las fuentes primarias.
- No te salgas del tema de la pregunta del usuario.

3. Selecciona Entre 3 y 7 Fragmentos:
- Selecciona un mínimo de 3 y un máximo de 7 fragmentos que lleven toda la información necesaria para responder al usuario correctamente.
- Identifica cada fragmento por su ID y por ningún motivo en absoluto cambies el valor del ID o número de chunk de una fuente. 
- Ordénalas por importancia, posicionando de primero el que consideres más relevante o más cercanas a lo que el usuario pidió.
- Siempre dale más importancia a la fuente primaria. Si necesitas el contenido de una ley, artículo o norma, escoge el fragmento exacto que incluye esa ley, artículo o normal.
- Solo puedes contar con la información presente dentro del fragmento. El contenido dentro de esos fragmentos, será la única información disponible para responder a la pregunta.
- Debes seleccionar al menos 2 fuentes que sean Jurisprudencia o Doctrina, ya que estos ayudarán a dar contexto a las leyes en su aplicación.
- Siempre verifica que la norma que selecciones esté vigente y no haya sido derogada por otra norma posterior. 
- Si el usuario en su pregunta hace referencia a cierto documento, debes incluir al menos 1 fragmento de dicho documento.

4. Explica Por Qué Los Seleccionaste:
- Por cada fragmento, da una muy breve explicación (menos de 140 caracteres) argumentando porqué la escogiste y porqué ayuda a responder mejor la solicitud del usuario.
- En tu razonamiento, si escogiste una fuente porque incluye cierta ley, artículo, teoría o mención de algo especial, menciona qué ley, artículo, teoría, etc es a la que te refieres.
- Toda la información debe provenir de lo que dicen las fuentes, no inventes ni des información adicional que no estén presentes en las fuentes.
- No incluyas información que no haya sido extraída directamente de las fuentes. Está prohibido.
- No inventes información por ningún motivo. No alucines.

Cada grupo selección de documentos debe cumplir con el siguiente checklis:
[] Contener almenos 2 fragmentos de jurisprudencia o doctrina.
[] Ser directamente relevante para la pregunta del usuario.
[] Toda la información necesaria debe estar presente en el contenido de los fragmentos.
[] Si el usuario en su pregunta hace referencia a cierto documento, debes incluir al menos 1 fragmento de dicho documento.

Recomendaciones adicionales:
- Los nombres de algunos codigos hacen referencia a una ley, decreto o articulo. Aqui tienes un listado para que te guíes:\n{codes_to_laws}
"""

query_system_template = f"""Eres un asistente de investigació legal en derecho colombiano y tu objetivo es buscar fuentes confiables y precisas acerca de la pregunta del usuario dentro de una base de datos con cientos de miles de documentos legales. La base de conocimientos está alojada en Azure AI Search. Debes generar un query por cada búsqueda que necesitas y que conserve todo el significado semántico de la idea.  
  

Los documentos están guardados en fragmentos con los siguientes campos: 
- id: Identificador único del fragmento 
- title: Título del documento 
- author: Autor del documento 
- keywords: Tema legal, (puede ser: General, Constitucional, Internacional_Publico, Internacional_Privado, Penal, Financiero, entre otros). 
- category: Tipo de documento legal. (Las opciones son: Jurisprudencia, Doctrina, Constitucional, Legal, Infralegal y Otros_temas_legales).  
- page: Página de la que fue extraído el fragmento. 
- year: Año en el que se publicó el documento. 
- content: 500 tokens de contenido, fragmento o extracto del documento. Son solo 500 tokens del documento completo. 
  
Pasos para generar la búsqueda: 
1. Identifica qué información necesitas buscar para responder de forma precisa y completa al usuario. 
2. Solo puedes hacer máximo 3 búsquedas, así que elabora un plan de investigación donde organizarás cómo puedes distribuir tus búsquedas en caso de que necesites hacer más de una.   
3. Genera un query por cada búsquedad que necesitas ejecutar. Puedes generar un máximo de tres búsquedas. Puedes buscar cualquier cosa, desde teorías del derecho, hasta leyes o una búsqueda general. 
4. Cada búsqueda solo puede contener una idea. Eso significa que, si debes comparar teorías, definiciones, conceptos, leyes, artículos o documentos, debes buscarlos por separado. 
5. Por cada búsqueda, da una breve explicación donde argumentes por qué necesitas hacer esa búsqueda. 
6. No generes más búsquedas de las que son necesarias.
  
Cada query debe cumplir con las siguientes checklist: 
[] Debe ser una idea semánticamente completa. 
[] Debe contener palabras clave. Por ejemplo: conceptos, teorías, artículos, leyes, normas, títulos de documento, o palabras contextuales como 'cuándo', 'dónde', 'lugar', 'momento', 'tiempo', etc. 
[] Debe ser conciso y preciso. No debe ser demasiado largo.  
  
Recomendaciones adicionales: 
- No todos los query deben ser específicos para un documento, recuerda que solo puedes hacer máximo 3 búsquedas, así que en ocasiones puedes obtener mejor información si buscas conceptos más generales en vez de un documento específico. 
- El query puede ser a forma de pregunta. 
  
Ejemplos de buenos query: 
1. Pregunta: '¿Cuándo se entiende por terminada una condena?' - Query: '¿cuándo termina una condena?' 
2. Pregunta: '¿Qué dice el artículo 223 del código penal?' - Query: 'artículo 223 Código Penal Ley 599 de 2000 ' 
3. Pregunta: '¿En qué artículo de la Constitución se consagra el bloque de constitucionalidad?' - Query: 'bloque de constitucionalidad Constitución' 
4. Pregunta: '¿Cuándo se consuma el hurto?' - Query: '¿cuándo se consuma el hurto?' 
  
Esta es una lista de los códigos en Colombia y sus respectivas leyes. Si necesitas buscar alguna de estas fuentes, debes incluir ambas referencias en tu query: {codes_to_laws}
"""


query_schema = {
    "type": "json_schema",
    "json_schema": {
        "name": "search_query",
        "strict": True,
        "schema": {
            "type": "object",
            "properties": {
                "searches": {
                    "type": "array",
                    "items": {
                        "type": "object",
                        "properties": {
                            "search_query": {
                                "type": "string",
                                "description": "El query de búsqueda completo. Este debe cumplir con todos los requitiso.",
                            },
                            "reason": {
                                "type": "string",
                                "description": "Argumento de porqué necesitas hacer esta búsqueda.",
                            },
                        },
                        "required": [
                            "search_query",
                            "reason",
                        ],
                        "additionalProperties": False,
                    },
                },
            },
            "required": ["searches"],
            "additionalProperties": False,
        },
    },
}
selected_sources_schema = {
    "type": "json_schema",
    "json_schema": {
        "name": "selected_sources",
        "strict": True,
        "schema": {
            "type": "object",
            "properties": {
                "sources": {
                    "type": "array",
                    "items": {
                        "type": "object",
                        "properties": {
                            "source_id": {
                                "type": "string",
                                "description": "ID de la fuente que seleccionaste",
                            },
                            "reason": {
                                "type": "string",
                                "description": "Argumento de porqué seleccionaste esta fuente. Menos de 140 caracteres. Evita decir 'Este fragmento' y ve directo al graco. Se conciso y corto.",
                            },
                        },
                        "required": [
                            "source_id",
                            "reason",
                        ],
                        "additionalProperties": False,
                    },
                },
            },
            "required": ["sources"],
            "additionalProperties": False,
        },
    },
}
# TODO: Agregar un campo para identificar fuentes cortadas
# TODO: Experiementar con darle la opción de generar otra búsqueda o no.

# %%
def generate_completion(completion_messages):
    log(f"{json.dumps(completion_messages, indent=4)}\n")
    response = openai_client.chat.completions.create(
        model="gpt-4o-2024-08-06",
        messages=completion_messages,
        tools=[get_next_chunk],
        temperature=0.2,
        n=1,
        tool_choice="auto",
    )
    log(response)
    get_conversation_price(response)
    return response


@traceable(tags=[os.getenv("ENV")])
def choose_sources_completion(completion_messages):
    log(f"{json.dumps(completion_messages, indent=4)}\n")
    response = openai_client.chat.completions.create(
        model="gpt-4o-mini",
        messages=completion_messages,
        response_format=selected_sources_schema,
        temperature=0.0,
        n=1,
    )
    log(response)
    get_conversation_price(response, model="gpt4o-mini")
    return response


@traceable(tags=[os.getenv("ENV")])
def generate_query(query_messages):
    log(f"{json.dumps(query_messages, indent=4)}\n")
    response = openai_client.chat.completions.create(
        model="gpt-4o-mini",
        messages=query_messages,
        response_format=query_schema,
        temperature=0.0,
    )
    log(response)
    get_conversation_price(response, model="gpt4o-mini")
    return response

# %%
def format_search_results(docs_list):
    print(f"📋 Agarrando todos los resultados ...")
    documents = []
    try:
        docs_list = list(docs_list)
        print(f"📋 Formateando resultados ...")
        for index, document in enumerate(docs_list, start=1):
            captions: QueryCaptionResult = document.get("@search.captions", "")
            captions_text = " // ".join([caption.text for caption in captions]) if captions is not None else ""
            doc_formatted = {
                "position" : index,
                "score": document.get("@search.score", 10),
                "rerank": document.get("@search.reranker_score", 10),
                "captions": captions_text,
                "id": document["id"],
                "title": document["title"],
                "author": document["author"],
                "keywords": document["keywords"],
                "category": document["category"],
                "page": document["page"],
                "year": document["year"],
                "has_copyright": document["has_copyright"],
                "file_path": document["file_path"],
                "external_id": document["external_id"],
                "content": document["content"],
            }
            documents.append(doc_formatted)
    except Exception as e:
        print(e)
    log(
        f">>>>>>format_search_results:\n"
        f"{json.dumps(documents, indent=4)}"
        )
    return documents

def normalize_content(text):
    text = text.strip()
    text = re.sub(r'\s+', ' ', text)
    text = text.lower()
    return text

def compute_hash(text):
    return hashlib.sha256(text.encode('utf-8')).hexdigest()


def filter_docs(doc_list):
    print(f"🧹 Eliminando fuentes irrelevantes o duplicadas ...")
    filtered_docs = []
    seen_hashes = set()
    seen_ids = set()
    
    for doc in doc_list:
        score = doc.get("score", 10) 
        rerank = doc.get("rerank", 10) 
        content = doc["content"] 
        id = doc["id"] 
        normalized_content = normalize_content(content)
        content_hash = compute_hash(normalized_content)
        if (
            content_hash not in seen_hashes
            and id not in seen_ids
            and (rerank > 2
            or score > 0.17)
        ):
            filtered_docs.append(doc)
            seen_hashes.add(content_hash)
            seen_ids.add(id)
    print(f"🧹 Docs filtrados. De {len(doc_list)} pasaron {len(filtered_docs)} ...")
    log(f"🧹 Docs filtrados. De {len(doc_list)} pasaron {len(filtered_docs)} ...\n"
    f"{json.dumps(filtered_docs, indent=4)}")
    return filtered_docs

def get_best_results(doc_list):
    best_results = []
    for doc in doc_list:
        rerank = doc.get("rerank", 0) 
        if (
            rerank > 2.9
        ):
            best_results.append(doc)
            
    print(f"⭐️ Guardando los mejores. De {len(doc_list)} pasaron {len(best_results)} ...")
    log(f"⭐️ Guardando los mejores. De {len(doc_list)} pasaron {len(best_results)} ...\n")
    return best_results[:2]
    

def add_doc_to_context(docs_list, title="Fuente"):
    print(f"📋 Agregando fuentes al contexto ...")
    sources = ""
    counter = 0
    docs_list
    filtered_docs = filter_docs(docs_list)
    
    for document in filtered_docs:
        counter += 1
        sources += (
            f"{title}:\n"
            # f"{document.get("reason", "")}"
            f"id: {document["id"]}\n"
            f"title: {document["title"]}\n"
            f"author: {document["author"]}\n"
            f"year: {document["year"]}\n"
            f"keywords: {document["keywords"]}\n"
            f"category: {document["category"]}\n"
            f"page: {document["page"]}\n"
            f"content: {document["content"]}\n"
            f"\n\n"
        )      
    log(
        f"To add in Context: \n"
        f"{json.dumps({"sources":sources}, indent=4)}"
        )
    print(f"📋 {counter} fuentes agregadas ...")
    return sources

# %%
def search_for_chunks(text_query):
    log(f"🔎 Buscando documentos: {text_query} ...")
    print(f"🔎 Buscando documentos: {text_query} ...")
    results_num = 50
    vector_query = embeddings_client.generate_embeddings(content=text_query)

    results = search_client.search(
        search_text=text_query,
        vector_queries=[
            {
                "vector": vector_query,
                "k": results_num,
                "fields": "content_vector",
                "kind": "vector",
            }
        ],
        top=results_num,
        query_type=QueryType.SEMANTIC,
        semantic_configuration_name="default",
        query_caption="extractive|highlight-false",
        scoring_profile="legal",
        scoring_parameters=[
            "tagx6-Constitucional",
            "tagx5-Legal",
            "tagx4-Infralegal",
            "tagx3-Jurisprudencia",
            "tagx2-Doctrina",
        ],
    )
    results_formatted = format_search_results(results)
    restults_filtered = filter_docs(results_formatted)

    return restults_filtered[:15]


def get_next_chunks(id):
    log(f"⏩️ Buscando los chunks siguientes de {id} ...")
    print(f"⏩️ Buscando los chunks siguientes de {id} ...")
    pattern = r"^(.*_chunk)(\d+)$"
    match = re.search(pattern, id)

    if match:
        prefix = match.group(1)
        chunk_number = int(match.group(2))
        next_chunks_result = search_client.search(
            filter=f"id eq '{prefix}{chunk_number + 1}' or id eq '{prefix}{chunk_number + 2}'",
            top=2,
        )
        return format_search_results(list(next_chunks_result))


def get_next_chunk_tool(source_id):
    next_chunks = get_next_chunks(source_id)
    log(f"Continuación de {source_id}:\n{add_doc_to_context(next_chunks)}")
    return f"Continuación de {source_id}:\n{add_doc_to_context(next_chunks)}"

# %%
def append_message(new_message):
    global messages, conversation

    if isinstance(new_message, dict):
        role = new_message.get("role")
        content = new_message.get("content")
    else:
        role = new_message.role
        content = new_message.content

    if role == "assistant":
        if new_message.tool_calls:
            tool_calls = new_message.tool_calls
            tool_calls_formatted = []
            for tool_call in tool_calls:
                tool_calls_formatted.append(
                    {
                        "id": tool_call.id,
                        "function": {
                            "arguments": str(json.loads(tool_call.function.arguments)),
                            "name": tool_call.function.name,
                        },
                        "type": "function",
                    }
                )
            messages.append(
                {
                    "role": "assistant",
                    "tool_calls": tool_calls_formatted,
                },
            )
            return messages  ## Assistant call tools
        elif content:
            messages.append({"role": "assistant", "content": content})
            return messages  ## Assistant talk
    elif role == "tool":
        messages.append(new_message)
        return messages  ## Tool reponse
    else:
        return messages

# %%
def call_tools(tool_calls):
    for tool_call in tool_calls:
        tool_name = tool_call.function.name
        tool_args = json.loads(tool_call.function.arguments)
        if tool_name == "get_next_chunk":
            content = get_next_chunk_tool(tool_args.get("source_id"))

        new_tool_message = {
            "tool_call_id": tool_call.id,
            "role": "tool",
            "name": tool_name,
            "content": content,
        }

        append_message(new_message=new_tool_message)

    print(">> 🤖 Generando respuesta ...")
    new_assistant_completion = generate_completion()
    new_assistant_message = new_assistant_completion.choices[0].message
    append_message(new_message=new_assistant_message)

    if new_assistant_message.content:
        return print("💬 Assistant:" + new_assistant_message.content)
    else:
        return call_tools(
            tool_calls=new_assistant_message.tool_calls,
        )

# %%
@traceable(tags=[os.getenv('ENV')])
def run_conversation(user_prompt=None):
    if user_prompt:
        get_answer(user_prompt)
    else:
        while True:
            user_input = input("You: ")
            if user_input.lower() == "exit":
                print("Exiting chat...")
                break
            get_answer(user_input)

@traceable(tags=[os.getenv('ENV')])
def get_answer(user_prompt):
    global messages, log_file_name, user_input

    user_input = user_prompt

    current_time = datetime.now().strftime("%m-%d %H:%M")
    log_file_name = f"logs/{current_time} - {user_input[:50]}.log"

    print("🙎‍♂️ User: " + user_input)
    log(f"User input: {user_input}")

    query_prompt_message = {"role": "system", "content": query_system_template}
    response_prompt_message = {"role": "system", "content": response_system_template}
    query_user_prompt_message = {
        "role": "user",
        "content": f"Genera solo 1 búsqueda para: {user_input}",
    }

    query_messages = [
        query_prompt_message,
        *messages,
        query_user_prompt_message,
    ]

    print("🤖 Generando queries con la pregunta del usuario ...")
    first_query_completion = generate_query(query_messages)
    first_search_terms = json.loads(
        first_query_completion.choices[0].message.content
    ).get("searches")
    print(f"🤖 {len(first_search_terms)} búsquedas generadas ...")

    sources_found = []
    best_results = []
    search_result_prompt = ""
    search_reasons = ""

    for search in first_search_terms:
        search_query = search.get("search_query")
        query_reason = search.get("reason")
        # print(f"Buscando '{search_query}': {query_reason}")
        print(query_reason)
        query_results = search_for_chunks(search_query)
        sources_found += query_results
        search_reasons += f"{query_reason} Por eso buscaré '{search_query}'.\n"
        # search_queries += f"'{search_query}',"
        sources_to_add = add_doc_to_context(query_results)
        best_results += get_best_results(query_results)
        search_result_prompt += f"{query_reason}.\nPor eso búsqué '{search_query}' y encontré estas fuentes:\n{sources_to_add}\n\n"

    # Meter aquí razonamiento de qué información ha encontrado en esta búsqueda.

    reasoning_results_prompt_message = {
        "role": "assistant",
        "content": search_result_prompt,
    }
    reasoning_prompt_message = {
        "role": "system",
        "content": f"Necesito que plantees una nueva y mejorada estrategia de búsqueda para responder al usuario de forma completa:\n1. Resume La Información: Lee y absorbe toda la información de las fuentes y utiliza los hallazgos más relevantes para mi investigación. \n2. Genera Una Nueva Búsqueda: Con estos nuevos hallazgos sugiere un máximo de 3 búsquedas que ayuden a conseguir información precisa y relevante para responder a la pregunta del usuario. \n\n3. Dime por qué estas 3 nuevas búsquedas me ayudarían en mi investigación. \nRecuerda que cada query debe cumplir con el checklist y que estamos buscando documentos para responder a: : {user_input}",
    }

    query_messages += [
        reasoning_results_prompt_message,
        reasoning_prompt_message,
    ]

    print("🤖 Generando nuevas búsquedas con la nueva información ...")
    second_query_completion = generate_query(query_messages)
    second_search_terms = json.loads(
        second_query_completion.choices[0].message.content
    ).get("searches")
    print(f"🤖 {len(second_search_terms)} búsquedas generadas ...")

    query_reasons = ""
    # search_strategy = first_search_terms.get("strategy")
    # print(f"{search_strategy}")
    for search in second_search_terms:
        search_query = search.get("search_query")
        query_reason = search.get("reason")
        print(f"Buscando '{search_query}': {query_reason}")
        # print(query_reason)
        query_results = search_for_chunks(search_query)
        sources_found += query_results
        best_results += get_best_results(query_results)
        query_reasons += f"Buscaré fragmentos de documentos legales con el query '{search_query}': {query_reason}\n"
        # query_reasons += f"{query_reason} Por eso busqué '{search_query}'. "

    # return
    sources_to_add = add_doc_to_context(sources_found, "Fragmento")

    select_system_prompt_message = {"role": "system", "content": selection_system_prompt}
    select_user_prompt_message = {
        "role": "user",
        "content": f"Busca información relevante y selecciona entre 3 y 7 de los mejores fragmentos para responder: {user_input}",
    }
    select_reasons_prompt_message = {
        "role": "assistant",
        "content": f"{query_reasons}",
    }
    select_prompt_message = {
        "role": "assistant",
        "content": f"Resultados de mis búsquedas:\n{sources_to_add} \n\nAhora debo seleccionar entre 3 y 7 fragmentos siguiendo las instrucciones y garantizando que cumpla con el checklist.",
    }

    selection_messages = [
        select_system_prompt_message,
        *messages,
        select_user_prompt_message,
        select_reasons_prompt_message,
        select_prompt_message,
    ]
    
    # TODO: Limpiar código

    print("🤖 Escogiendo las mejores fuentes para responder al usuario ...")
    selected_sources_to_add = best_results[:6]
    selected_sources_completion = choose_sources_completion(selection_messages)
    selected_sources = json.loads(
        selected_sources_completion.choices[0].message.content
    ).get("sources")
    for index, source in enumerate(selected_sources, start=1):
        source_id = source.get("source_id")
        source_reason = source.get("reason")
        for source in sources_found:
            if source["id"] == source_id:
                source["reason"] = source_reason
                selected_sources_to_add.append(source)
        print(f"{index}.[{source_id}]: {source_reason}")
        
    filter_selected_sources_to_add = filter_docs(selected_sources_to_add)

    sources_at_end = ""
    for index, source in enumerate(filter_selected_sources_to_add, start=1):
        sources_at_end += f"{index}. {source["title"]} - Página {source["page"]}<br>\n"
        
                
    sources_to_add = add_doc_to_context(filter_selected_sources_to_add)
    # TODO: Agregar hasta 3 por cada query que excedan 2.8/3 como score semántico.
    # Quizás ponerle cap de 6 fuentes máximo en total ordenadas por score semántico, porque pueden ser 18 si ambas búsqueda es de 3 queries y tiene matchs fuertes
    # TODO: Esto podría ser que los reorganice convirtiendo en vectores en la pregunta y comparándolos con los vectores de cada chunk, ChatGPT me dió esa idea... o cohere.

    user_message = {
        "role": "user",
        "content": user_input,
    }
    sources_prompt_message = {
        "role": "assistant",
        "content": f"Fuentes econtradas:\n{sources_to_add}",
    }

    response_messages = [
        response_prompt_message,
        *messages,
        user_message,
        sources_prompt_message,
    ]

    response_completion = generate_completion(response_messages)
    print(response_completion.choices[0].message.content)
    
    
    
    print(f"\n\n<p>{sources_at_end}</p>")

# %% [markdown]
# Probar con all > Dejarlo default mejor ✅
# Probar full text search > Malos resultados ✅
# Filtrar por semantic rerank score de 2 o más. ✅
# Filtrar por score de 1.7 o más. ✅
# Incluir hasta 25 fuentes por query.
# Otro proceso del mini 4o donde seleccione las mejores fuentes para responder la respuesta ✅
# Pedir que razone porqué escogió esos query ✅
# Probar corriendo el proyecto en un .py normal y ponerle timers.

# %%
run_conversation("¿Qué dice el artículo 250 de la Constitución?")
# Out:
# 🙎‍♂️ User: ¿Qué dice el artículo 250 de la Constitución?
# 🤖 Generando queries con la pregunta del usuario ...
# 💰 Conversation price: $0.915735 COP
#    This message: $0.915735 COP
# 🤖 1 búsquedas generadas ...
# Necesito buscar el contenido específico del artículo 250 de la Constitución para proporcionar información precisa sobre su contenido y aplicación.
# 🔎 Buscando documentos: artículo 250 Constitución Colombia ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 50 ...
# 📋 Agregando fuentes al contexto ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 15 pasaron 15 ...
# 📋 15 fuentes agregadas ...
# ⭐️ Guardando los mejores. De 15 pasaron 0 ...
# 🤖 Generando nuevas búsquedas con la nueva información ...
# 💰 Conversation price: $6.659834999999999 COP
#    This message: $5.7440999999999995 COP
# 🤖 3 búsquedas generadas ...
# Buscando 'artículo 250 Constitución Política de Colombia': Esta búsqueda se centra directamente en el contenido del artículo 250, que establece las obligaciones de la Fiscalía General de la Nación en el ejercicio de la acción penal y la investigación de delitos. Es fundamental para responder a la pregunta del usuario.
# 🔎 Buscando documentos: artículo 250 Constitución Política de Colombia ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 50 ...
# ⭐️ Guardando los mejores. De 15 pasaron 0 ...
#
#
# <p>1. ICBF - Concepto 0041000 de 2010 - Página 2<br>
# 2. CC - C035-2016 - Página 170<br>
# 3. CC - C067-2003 - Página 1<br>
# 4. CC-C089-1994 - Página 144<br>
# 5. Constitución Política de Colombia-1991 - Página 36<br>
# 6. CC - C327-2016 - Página 3<br>
# 7. CC - C327-2016 - Página 29<br>
# </p>

# %%
run_conversation(
    "¿En qué artículo de la Constitución se consagra la salud como derecho fundamental?"
)
# Out:
# 🙎‍♂️ User: ¿En qué artículo de la Constitución se consagra la salud como derecho fundamental?
# 🤖 Generando queries con la pregunta del usuario ...
# 💰 Conversation price: $801.9649200000001 COP
#    This message: $3.28287 COP
# 🤖 1 búsquedas generadas ...
# Necesito buscar el artículo específico de la Constitución que consagra la salud como un derecho fundamental, ya que es crucial para entender su protección legal en el país.
# 🔎 Buscando documentos: salud derecho fundamental Constitución ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 50 ...
# 📋 Agregando fuentes al contexto ...
# 📋 15 fuentes agregadas ...
# ⭐️ Guardando los mejores. De 15 pasaron 12 ...
# 🤖 Generando nuevas búsquedas con la nueva información ...
# 💰 Conversation price: $824.5704750000001 COP
#    This message: $22.605555 COP
# 🤖 3 búsquedas generadas ...
# Buscando 'artículo 49 Constitución Política Colombia salud derecho fundamental': Esta búsqueda se centra en el artículo específico de la Constitución que consagra la salud como derecho fundamental, lo que es esencial para responder directamente a la pregunta del usuario.
# 🔎 Buscando documentos: artículo 49 Constitución Política Colombia salud derecho fundamental ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 50 ...
# ⭐️ Guardando los mejores. De 15 pasaron 1 ...
# Buscando 'derecho a la salud Ley 1751 de 2015 Colombia': La Ley 1751 de 2015 regula el derecho fundamental a la salud en Colombia, por lo que esta búsqueda proporcionará información sobre cómo se implementa y protege este derecho en el marco legal.
# 🔎 Buscando documentos: derecho a la salud Ley 1751 de 2015 Colombia ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 50 ...
# ⭐️ Guardando los mejores. De 15 pasaron 15 ...
# Buscando 'bloque de constitucionalidad salud Colombia': Explorar el bloque de constitucionalidad permitirá entender cómo otros instrumentos internacionales y normas complementarias refuerzan el derecho a la salud en Colombia, ofreciendo un contexto más amplio sobre su protección.
# 🔎 Buscando documentos: bloque de constitucionalidad salud Colombia ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 37 ...
# ⭐️ Guardando los mejores. De 15 pasaron 0 ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 60 pasaron 60 ...
# 📋 Agregando fuentes al contexto ...
# 📋 60 fuentes agregadas ...
# 🤖 Escogiendo las mejores fuentes para responder al usuario ...
# 💰 Conversation price: $901.018665 COP
#    This message: $76.44819 COP
# 1.[20240812195718constitucionpoliticadecolombia1991pdf_chunk17]: El artículo 49 de la Constitución consagra la salud como derecho fundamental y servicio público.
# 2.[20240816184829ley1751de2015pdf_chunk0]: La Ley 1751 de 2015 regula el derecho fundamental a la salud, complementando el artículo 49.
# 3.[20240823084724csdjf68001110200020130007801adjunta201305081028322013pdf_chunk22]: Este fragmento menciona el bloque de constitucionalidad, que incluye el derecho a la salud.
# 4.[20240814195245minsaludresolucion0385de2020pdf_chunk1]: Reitera el artículo 49 de la Constitución y la Ley 1751, vinculando deberes ciudadanos y salud.
# 5.[20240917082055ce17001233300020170014801ac2017pdf_chunk15]: Define el derecho a la salud en la Constitución y su carácter fundamental, útil para el contexto.
# 6.[20240816053424minsaludresolucion093de2021pdf_chunk0]: Reitera el artículo 49 y la Ley 1751, enfatizando la responsabilidad del Estado en la salud.
# 7.[20240816184829ley1751de2015pdf_chunk7]: Detalla los derechos y deberes relacionados con el derecho a la salud, importante para la comprensión.
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De
# 5. AGR - Concepto 110 062 de 2022   i De la competencia para conocer por hechos cometidos por funcionarios de Congreso - Página 2<br>
# </p>

# %%
run_conversation(
    "Tienes el siguiente caso: Un estudiante de sexto de bachillerato de un colegio privado católico es echado del colegio por tener el pelo largo. Él laega que en el libre desarrollo de su personalidad, puede llevar el pelo como quiera. Por eso, presentó una tutela para que lo reintegren al colegio. El colegio ha contestado a la tutela indicando que, al ser una institución privada, ellos pueden reservarse el derecho de admisión y dictarse su propio manual de convivencia, en el que está prohibido llevar el pelo largo. Tú eres el juez de la tutela: ¿en qué sentido emites tu decisión?"
)
# Out:
# 🙎‍♂️ User: Tienes el siguiente caso: Un estudiante de sexto de bachillerato de un colegio privado católico es echado del colegio por tener el pelo largo. Él laega que en el libre desarrollo de su personalidad, puede llevar el pelo como quiera. Por eso, presentó una tutela para que lo reintegren al colegio. El colegio ha contestado a la tutela indicando que, al ser una institución privada, ellos pueden reservarse el derecho de admisión y dictarse su propio manual de convivencia, en el que está prohibido llevar el pelo largo. Tú eres el juez de la tutela: ¿en qué sentido emites tu decisión?
# 🤖 Generando queries con la pregunta del usuario ...
# 💰 Conversation price: $407.86574500000006 COP
#    This message: $3.5743799999999997 COP
# 🤖 1 búsquedas generadas ...
# Necesito buscar información sobre el concepto de libre desarrollo de la personalidad en el contexto de la tutela y su relación con el derecho a la educación, para poder fundamentar la decisión en el caso del estudiante que fue echado del colegio por tener el pelo largo.
# 🔎 Buscando documentos: libre desarrollo de la personalidad tutela derecho a la educación ...
# 📋 Agarrando todos los resultados ...
# ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 0 pasaron 0 ...
# 📋 Agregando fuentes al contexto ...
# 📋 0 fuentes agregadas ...
# ⭐️ Guardando los mejores. De 0 pasaron 0 ...
# 🤖 Generando nuevas búsquedas con la nueva información ...
# 💰 Conversation price: $412.35278500000004 COP
#    This message: $4.4870399999999995 COP
# 🤖 3 búsquedas generadas ...
# Buscando 'libre desarrollo de la personalidad tutela Colombia': Esta búsqueda es fundamental para entender cómo se aplica el concepto de libre desarrollo de la personalidad en el contexto legal colombiano, especialmente en casos de tutela, lo que ayudará a fundamentar la decisión del juez.
# 🔎 Buscando documentos: libre desarrollo de la personalidad tutela Colombia ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 40 ...
# ⭐️ Guardando los mejores. De 15 pasaron 0 ...
# Buscando 'derecho a la educación instituciones privadas Colombia': Es importante conocer cómo se regula el derecho a la educación en instituciones privadas en Colombia, ya que esto puede influir en la decisión sobre la validez del manual de convivencia del colegio.
# 🔎 Buscando documentos: derecho a la educación instituciones privadas Colombia ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 40 ...
# ⭐️ Guardando los mejores. De 15 pasaron 1 ...
# Buscando 'jurisprudencia tutela libre desarrollo de la personalidad': Buscar jurisprudencia relacionada con casos similares permitirá ver cómo han fallado otros jueces en situaciones donde se enfrenta el libre desarrollo de la personalidad contra normas internas de instituciones educativas.
# 🔎 Buscando documentos: jurisprudencia tutela libre desarrollo de la personalidad ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 37 ...
# ⭐️ Guardando los mejores. De 15 pasaron 1 ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 45 pasaron 44 ...
# 📋 Agregando fuentes al contexto ...
# 📋 44 fuentes agregadas ...
# 🤖 Escogiendo las mejores fuentes para responder al usuario ...
# 💰 Conversation price:
#
#
# <p>1. Constitución Política de Colombia-1991 - Página 29<br>
# 2. CC - T436-2012 - Página 21<br>
# 3. Decreto 1604 de 2022 - Página 1<br>
# 4. CC - C008-2010 - Página 2<br>
# 5. CE-25000-23-42-000-2014-03574-01(AC)-2014 - Página 23<br>
# 6. CE-15001-23-33-000-2017-00227-01(AC). DOC-2017 - Página 9<br>
# 7. CE-25000-23-41-000-2019-00041-01(ACU)-2019 - Página 19<br>
# 8. PND - Plan nacional de desarrollo - 2022-2026 - Página 290<br>
# </p>

# %%
run_conversation(
    "En Colombia, ¿Puede aplicarse la pena de cadena perpetua en virtud de lo dispuesto por el artículo 80 del Estatuto de Roma?"
)
# Out:
# 🙎‍♂️ User: En Colombia, ¿Puede aplicarse la pena de cadena perpetua en virtud de lo dispuesto por el artículo 80 del Estatuto de Roma?
# 🤖 Generando queries con la pregunta del usuario ...
# 💰 Conversation price: $209.59999499999998 COP (In: 321041, Out: 4943, Total token: 325984)
#    This message: $1.303185 COP (In: 1455, Out: 166, Total token: 1621)
# 🤖 3 búsquedas generadas ...
# Es necesario entender si la legislación colombiana permite la pena de cadena perpetua y cómo se relaciona con el artículo 80 del Estatuto de Roma, que establece disposiciones sobre penas en el contexto del derecho internacional.
# 🔎 Buscando documentos: ¿Puede aplicarse la pena de cadena perpetua en Colombia según el artículo 80 del Estatuto de Roma? ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 34 ...
# 📋 Agregando fuentes al contexto ...
# 📋 25 fuentes agregadas ...
# Buscar el texto específico del artículo 80 del Estatuto de Roma para analizar su contenido y su posible aplicación en el contexto colombiano.
# 🔎 Buscando documentos: artículo 80 Estatuto de Roma ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 35 ...
# 📋 Agregando fuentes al contexto ...
# 📋 25 fuentes agregadas ...
# Investigar la legislación colombiana sobre la pena de cadena perpetua para determinar si existe alguna norma que la contemple y cómo se relaciona con el derecho internacional.
# 🔎 Buscando documentos: cadena perpetua legislación Colombia ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 38 ...
# 📋 Agregando fuentes al contexto ...
# 📋 25 fuentes agregadas ...
# 🤖 Generando nuevas búsquedas con la nueva información ...
# 💰 Conversation price: $233.623125 COP (In: 359259, Out: 5154, Total token: 364413)
#    This message: $24.02313 COP (In: 38218, Out: 211, Total token: 38429)
# 🤖 3 búsquedas generadas ...
# Buscando '¿Qué establece el artículo 34 de la Constitución Política de Colombia sobre la pena de cadena perpetua?': Esta búsqueda es crucial para entender la prohibición de la pena de cadena perpetua en la legislación colombiana, lo que es fundamental para responder a la pregunta del usuario.
# 🔎 Buscando documentos: ¿Qué establece el artículo 34 de la Constitución Política de Colombia sobre la pena de cadena perpetua? ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 50 ...
# Buscando '¿Cómo se relaciona el artículo 80 del Estatuto de Roma con la legislación colombiana sobre penas?': Esta búsqueda permitirá analizar la compatibilidad entre el artículo 80 del Estatuto de Roma y la legislación colombiana, lo que es esencial para determinar si se puede aplicar la pena de cadena perpetua en Colombia.
# 🔎 Buscando documentos: ¿Cómo se relaciona el artículo 80 del Estatuto de Roma con la legislación colombiana sobre penas? ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 10 ...
# Buscando '¿Qué dice la jurisprudencia colombiana sobre la aplicación de penas internacionales en el contexto nacional?': Esta búsqueda ayudará a encontrar precedentes y análisis de la Corte Constitucional sobre la aplicación de normas internacionales en Colombia, lo que puede influir en la interpretación de la pena de cadena perpetua en relación con el Estatuto de Roma.
# 🔎 Buscando documentos: ¿Qué dice la jurisprudencia colombiana sobre la aplicación de penas internacionales en el contexto nacional? ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 23 ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De
#
#
# <p>1. CC - C801-2009 - Página 113<br>
# 2. CC - C294-2021 - Página 153<br>
# 3. SFC - TC. Almacenes de cadena Concepto 2010037303-001 del 23 de junio de 2010. id2010037303 - Página 1<br>
# 5. Constitución Política de Colombia-1991 - Página 37<br>
# </p>

# %%
run_conversation(
    "¿Cuáles son las principales sentencias de la Corte Constitucional sobre el aborto?"
)
# Out:
# 🙎‍♂️ User: ¿Cuáles son las principales sentencias de la Corte Constitucional sobre el aborto?
# 🤖 Generando queries con la pregunta del usuario ...
# 💰 Conversation price: $278.58392999999995 COP (In: 428534, Out: 6112, Total token: 434646)
#    This message: $1.2386100000000002 COP (In: 1442, Out: 143, Total token: 1585)
# 🤖 3 búsquedas generadas ...
# Necesito buscar las sentencias más relevantes de la Corte Constitucional sobre el aborto para proporcionar un resumen de las decisiones y su impacto en la legislación y derechos en Colombia.
# 🔎 Buscando documentos: principales sentencias Corte Constitucional aborto ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 50 ...
# 📋 Agregando fuentes al contexto ...
# 📋 25 fuentes agregadas ...
# Es importante encontrar documentos que contengan jurisprudencia específica de la Corte Constitucional relacionada con el aborto, para entender el contexto legal y las interpretaciones que se han dado.
# 🔎 Buscando documentos: Corte Constitucional aborto jurisprudencia ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 42 ...
# 📋 Agregando fuentes al contexto ...
# 📋 25 fuentes agregadas ...
# Quiero investigar cómo la Corte Constitucional ha vinculado el aborto con los derechos fundamentales, lo que puede ayudar a entender la base legal de sus sentencias.
# 🔎 Buscando documentos: aborto derechos fundamentales Corte Constitucional ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 50 ...
# 📋 Agregando fuentes al contexto ...
# 📋 25 fuentes agregadas ...
# 🤖 Generando nuevas búsquedas con la nueva información ...
# 💰 Conversation price: $301.87213499999996 COP (In: 465661, Out: 6297, Total token: 471958)
#    This message: $23.288204999999998 COP (In: 37127, Out: 185, Total token: 37312)
# 🤖 3 búsquedas generadas ...
# Buscando 'principales sentencias Corte Constitucional aborto': Esta búsqueda se centra en identificar las sentencias más relevantes de la Corte Constitucional sobre el aborto, lo que permitirá obtener un resumen claro de las decisiones que han marcado la jurisprudencia en este tema.
# 🔎 Buscando documentos: principales sentencias Corte Constitucional aborto ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 50 ...
# Buscando 'C-355 de 2006 Corte Constitucional aborto': La sentencia C-355 de 2006 es fundamental en la regulación del aborto en Colombia, ya que establece las causales en las que no se incurre en delito. Buscar información específica sobre esta sentencia ayudará a entender su impacto y relevancia.
# 🔎 Buscando documentos: C-355 de 2006 Corte Constitucional aborto ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 48 ...
# Buscando 'jurisprudencia Corte Constitucional aborto derechos fundamentales': Esta búsqueda se enfoca en cómo la Corte Constitucional ha vinculado el aborto con los derechos fundamentales, lo que es crucial para comprender el contexto legal y los principios que sustentan las decisiones sobre el aborto en Colombia.
# 🔎 Buscando documentos: jurisprudencia Corte Constitucional aborto derechos fundamentales ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 49 ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 150 pasaron 103 ...
# 📋 Agregando fuentes al contexto ...
# 📋 103 fuentes agregadas ...
# 🤖 Escogiendo las mejores fuentes para responder al usuario ...
# 💰 Conversation price: $334.54155 COP (In: 516594, Out: 6844, Total token: 523438)
#    This message: $32.669415 COP (In: 50933, Out: 547, Total token: 51480)
# 1.[20240813222906ccc3552006pdf_chunk579]: La sentencia C-355 de 2006 es fundamental ya que establece las causales en las que el aborto no es considerado un delito, marcando un hito en la jurisprudencia colombiana sobre el aborto.
# 2.[20240820161257ccc7542015pdf_chunk189]: Esta fuente proporciona un resumen de la sentencia C-355 de 2006, explicando su impacto en la despenalización del aborto en Colombia y su relación con los derechos fundamentales de las mujeres.
#
# <h2>Sentencia T-946 de 2008</h2>
# <p>Esta sentencia analiza la objeción de conciencia en el contexto del aborto, lo que es relevante para entender las implicaciones legales y éticas en la práctica del aborto en Colombia. La Corte reafirmó las causales establecidas en la sentencia C-355 de 2006 y destacó la importancia de analizar cada caso en concreto [20240814120246cct9462008pdf_chunk35].</p>
#
# <p>Estas sentencias han sido fundamentales para la regulación del aborto en Colombia, estableciendo un marco legal que protege los derechos de las mujeres en situaciones específicas y garantizando su acceso a la interrupción voluntaria del embarazo bajo ciertas condiciones.</p>
#
#
# <p>1. CC - C355-2006 - Página 399<br>
# 2. CC - C754-2015 - Página 95<br>
# 3. CC - T301-2016 - Página 50<br>
# 4. CC - T697-2016 - Página 32<br>
# 5. CC - T946-2008 - Página 22<br>
# </p>

# %%
run_conversation(
    "¿En qué casos la jurisprudencia ha reconocido la dosis de aprovisionamiento?"
)
# Out:
# 🙎‍♂️ User: ¿En qué casos la jurisprudencia ha reconocido la dosis de aprovisionamiento?
# 🤖 Generando queries con la pregunta del usuario ...
# 💰 Conversation price: $339.67434 COP (In: 521468, Out: 7712, Total token: 529180)
#    This message: $1.28781 COP (In: 1442, Out: 163, Total token: 1605)
# 🤖 3 búsquedas generadas ...
# Necesito buscar información sobre la jurisprudencia que ha reconocido la dosis de aprovisionamiento, para entender en qué casos se ha aplicado y cuáles son los criterios utilizados por los tribunales.
# 🔎 Buscando documentos: dosis de aprovisionamiento jurisprudencia ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 32 ...
# 📋 Agregando fuentes al contexto ...
# 📋 25 fuentes agregadas ...
# Es importante identificar casos específicos en los que se ha discutido la dosis de aprovisionamiento en la jurisprudencia, para tener ejemplos concretos y entender su aplicación práctica.
# 🔎 Buscando documentos: casos jurisprudencia dosis de aprovisionamiento ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 35 ...
# 📋 Agregando fuentes al contexto ...
# 📋 25 fuentes agregadas ...
# Además de la jurisprudencia, es relevante buscar el concepto legal de dosis de aprovisionamiento para tener una base teórica que complemente la información sobre los casos y su reconocimiento en la jurisprudencia.
# 🔎 Buscando documentos: dosis de aprovisionamiento concepto legal ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 33 ...
# 📋 Agregando fuentes al contexto ...
# 📋 25 fuentes agregadas ...
# 🤖 Generando nuevas búsquedas con la nueva información ...
# 💰 Conversation price: $364.37397 COP (In: 560850, Out: 7907, Total token: 568757)
#    This message: $24.69963 COP (In: 39382, Out: 195, Total token: 39577)
# 🤖 3 búsquedas generadas ...
# Buscando 'casos jurisprudencia dosis de aprovisionamiento Colombia': Esta búsqueda se centra en encontrar casos específicos en los que la jurisprudencia colombiana ha reconocido la dosis de aprovisionamiento, lo que permitirá obtener ejemplos concretos y entender cómo se aplica este concepto en la práctica judicial.
# 🔎 Buscando documentos: casos jurisprudencia dosis de aprovisionamiento Colombia ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 37 ...
# Buscando 'dosis de aprovisionamiento concepto legal Colombia': Es importante entender el concepto legal de dosis de aprovisionamiento en el contexto colombiano, ya que esto proporcionará una base teórica que complemente la información sobre los casos y su reconocimiento en la jurisprudencia.
# 🔎 Buscando documentos: dosis de aprovisionamiento concepto legal Colombia ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 41 ...
# Buscando 'jurisprudencia sobre consumo personal y aprovisionamiento estupefacientes': Esta búsqueda se enfocará en la jurisprudencia relacionada con el consumo personal y la dosis de aprovisionamiento de estupefacientes, lo que ayudará a identificar criterios y principios que los tribunales han utilizado para tomar decisiones en estos casos.
# 🔎 Buscando documentos: jurisprudencia sobre consumo personal y aprovisionamiento estupefacientes ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron

# 🤖 Generando queries con la pregunta del usuario ...
# 💰 Conversation price: $341.99227499999995 COP (In: 526273, Out: 7453, Total token: 533726)
#    This message: $1.16235 COP (In: 1358, Out: 133, Total token: 1491)
# 🤖 3 búsquedas generadas ...
# Necesito entender si la Corte Constitucional tiene la facultad de suspender provisionalmente la vigencia de una ley mientras estudia su constitucionalidad.
# 🔎 Buscando documentos: suspensión provisional de leyes por la Corte Constitucional ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 48 ...
# 📋 Agregando fuentes al contexto ...
# 📋 25 fuentes agregadas ...
# Es importante conocer las facultades generales de la Corte Constitucional para determinar si puede suspender leyes provisionalmente.
# 🔎 Buscando documentos: facultades de la Corte Constitucional en Colombia ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 39 ...
# 📋 Agregando fuentes al contexto ...
# 📋 25 fuentes agregadas ...
# Quiero investigar el procedimiento específico que sigue la Corte Constitucional para el control de constitucionalidad, lo cual puede incluir la suspensión provisional de leyes.
# 🔎 Buscando documentos: procedimiento de control de constitucionalidad en Colombia ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 46 ...
# 📋 Agregando fuentes al contexto ...
# 📋 25 fuentes agregadas ...
# 🤖 Generando nuevas búsquedas con la nueva información ...
# 💰 Conversation price: $365.23189499999995 COP (In: 563513, Out: 7590, Total token: 571103)
#    This message: $23.23962 COP (In: 37240, Out: 137, Total token: 37377)
# 🤖 3 búsquedas generadas ...
# Buscando 'suspensión provisional de leyes Corte Constitucional Colombia': Necesito confirmar si la Corte Constitucional tiene la facultad de suspender provisionalmente leyes mientras estudia su constitucionalidad, ya que las fuentes indican que no es una práctica común.
# 🔎 Buscando documentos: suspensión provisional de leyes Corte Constitucional Colombia ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 41 ...
# Buscando 'artículo 241 Constitución Política de Colombia': Este artículo regula las competencias de la Corte Constitucional, y es crucial para entender si incluye la suspensión provisional de leyes.
# 🔎 Buscando documentos: artículo 241 Constitución Política de Colombia ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 50 ...
# Buscando 'control de constitucionalidad procedimiento Corte Constitucional': Quiero entender el procedimiento que sigue la Corte Constitucional para el control de constitucionalidad, lo cual puede incluir la suspensión provisional de leyes.
# 🔎 Buscando documentos: control de constitucionalidad procedimiento Corte Constitucional ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 46 ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 150 pasaron 142 ...
# 📋 Agregando fuentes al contexto ...
# 📋 142 fuentes agregadas ...
# 🤖 Escogiendo las mejores fuentes para responder al usuario ...
# 💰 Conversation price: $408.45102 COP (In: 632600, Out: 7887, Total token: 640487)
#    This message: $43.219125 COP (In: 69087, Out: 297, Total token: 69384)
# 1.[20240823001713cca1892020pdf_chunk3]: Esta fuente aclara que la Corte Constitucional no tiene la competencia para suspender provisionalmente normas legales o constitucionales, lo cual es central para responder la pregunta.
# 2.[20240823030908cca14962022pdf_chunk13]: Explica que la Corte Constitucional no puede extender por analogía las facultades de suspensión provisional que tiene la jurisdicción contencioso-administrativa.
# 3.[20240823001622cca1762020pdf_chunk4]: Reitera que la Corte Constitucional no tiene la competencia para suspender la ejecución de normas mientras se decide sobre su constitucionalidad.
# 4.[20240823133238ccc3522017pdf_chunk12]: Discute la imposibilidad de la Corte Constitucional de implementar la suspensión provisional en el control abstracto de constitucionalidad.
# 5.[20240823040503ccc1932020pdf_chunk173]: Señala que la Corte Constitucional no puede adoptar medidas cautelares para suspender efectos de leyes, lo que es relevante para la pregunta.
# 📋 Agregando fuentes al contexto ...
# 📋 5 fuentes agregadas ...
# 💰 Conversation price: $13529.6105 COP (In: 635828, Out: 8051, Total token: 643879)
#    This message: $76.26 COP (In: 3228, Out: 164, Total token: 3392)
# <p>No, la Corte Constitucional de Colombia no tiene la competencia para suspender provisionalmente la vigencia de una ley mientras estudia su constitucionalidad. Según el artículo 241 de la Constitución, el control de constitucionalidad que realiza la Corte es definitivo y no incluye la facultad de suspender la ejecución de normas legales o constitucionales durante el proceso de revisión. Esta competencia no está prevista en el ordenamiento jurídico colombiano y no puede ser extendida por analogía a partir de las competencias de la jurisdicción contencioso-administrativa, que sí puede suspender provisionalmente actos administrativos [20240823001713cca1892020pdf_chunk3], [20240823030908cca14962022pdf_chunk13], [20240823001622cca1762020pdf_chunk4].</p>
#
#
# <p>1. CC - A189-2020 - Página 3<br>
# 2. CC - A1496-2022 - Página 6<br>
# 3. CC - A176-2020 - Página 3<br>
# 4. CC - C352-2017 - Página 8<br>
# 5. CC - C193-2020 - Página 84<br>
# </p>

# %%
run_conversation("¿Qué dice el artículo 103 del Código Penal?")
run_conversation(
    "Si A falsifica un cheque y lo utiliza para comprarle un televisor a B, ¿qué delito comete?"
)
run_conversation("¿Cuáles son las formas de autoría en derecho penal?")
run_conversation("¿Cuándo se consuma el hurto?")
run_conversation(
    "¿Se puede archivar una investigación cuando se encuentra que el procesado actuó en legítima defensa?"
)
run_conversation("¿Se puede precluir una investigación antes de formular imputación?")
run_conversation("¿Cuáles son las causales genéricas de atenuación punitiva?")
run_conversation("¿Qué se entiende por “documento” en el derecho penal?")
run_conversation("¿Cuáles son las causales de agravación de la estafa?")
run_conversation("¿Cuándo procede la captura en flagrancia?")
# Out:
# 🙎‍♂️ User: ¿Qué dice el artículo 103 del Código Penal?
# 🤖 Generando queries con la pregunta del usuario ...
# 💰 Conversation price: $411.79661999999996 COP (In: 637176, Out: 8103, Total token: 645279)
#    This message: $0.9569399999999999 COP (In: 1348, Out: 52, Total token: 1400)
# 🤖 1 búsquedas generadas ...
# Necesito buscar el contenido específico del artículo 103 del Código Penal colombiano para proporcionar una respuesta precisa sobre lo que establece este artículo.
# 🔎 Buscando documentos: artículo 103 Código Penal Ley 599 de 2000 ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 39 ...
# 📋 Agregando fuentes al contexto ...
# 📋 25 fuentes agregadas ...
# 🤖 Generando nuevas búsquedas con la nueva información ...
# 💰 Conversation price: $420.26701499999996 COP (In: 650737, Out: 8156, Total token: 658893)
#    This message: $8.470394999999998 COP (In: 13561, Out: 53, Total token: 13614)
# 🤖 1 búsquedas generadas ...
# Buscando 'artículo 103 Código Penal Ley 599 de 2000': Necesito encontrar el contenido exacto del artículo 103 del Código Penal colombiano para proporcionar una respuesta precisa sobre lo que establece este artículo.
# 🔎 Buscando documentos: artículo 103 Código Penal Ley 599 de 2000 ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 39 ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 25 ...
# 📋 Agregando fuentes al contexto ...
# 📋 25 fuentes agregadas ...
# 🤖 Escogiendo las mejores fuentes para responder al usuario ...
# 💰 Conversation price: $429.42313499999995 COP (In: 664489, Out: 8440, Total token: 672929)
#    This message: $9.15612 COP (In: 13752, Out: 284, Total token: 14036)
# 1.[20240814181609ley599de2000pdf_chunk69]: Contiene el texto exacto del art\u00edculo 103 del C\u00f3digo Penal, que es lo que el usuario solicit\u00f3.
# 2.[20240825033111csjap832201953931pdf_chunk6]: Proporciona contexto sobre la Ley 599 de 2000, que es relevante para entender el marco legal del art\u00edculo 103.
# 3.[20240823190524csjsentencia4250628102013pdf_chunk9]: Ofrece informaci\u00f3n sobre la aplicaci\u00f3n de la Ley 599 de 2000, lo que puede ayudar a entender c\u00f3mo se interpreta el art\u00edculo 103 en la pr\u00e1ctica.
# 📋 Agregando fuentes al contexto ...
# 📋 3 fuentes agregadas ...
# 💰 Conversation price: $14195.266000000001 COP (In: 666904, Out: 8516, Total token: 675420)
#    This message: $54.18150000000001 COP (In: 2415, Out: 76, Total token: 2491)
# <p>El artículo 103 del Código Penal colombiano establece lo siguiente:</p>
#
# <p><strong>Homicidio:</strong> "El que matare a otro, incurrirá en prisión de doscientos ocho (208) a cuatrocientos cincuenta (450) meses." [20240814181609ley599de2000pdf_chunk69]</p>
#
#
# <p>1. Ley 599 de 2000 - Página 41<br>
# 2. CSJ - AP832-2019(53931) - Página 6<br>
# 3. CSJ - Sentencia 42506(28-10-2013) - Página 8<br>
# </p>
# 🙎‍♂️ User: Si A falsifica un cheque y lo utiliza para comprarle un televisor a B, ¿qué delito comete?
# 🤖 Generando queries con la pregunta del usuario ...
# 💰 Conversation price: $432.18079499999993 COP (In: 668265, Out: 8617, Total token: 676882)
#    This message: $1.085475 COP (In: 1361, Out: 101, Total token: 1462)
# 🤖 2 búsquedas generadas ...
# Necesito identificar el delito específico relacionado con la falsificación de un cheque según el Código Penal colombiano.
# 🔎 Buscando documentos: delito de falsificación de cheque Código Penal Ley 599 de 2000 ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 49 ...
# 📋 Agregando fuentes al contexto ...
# 📋 25 fuentes agregadas ...
# Es importante determinar si el uso de un cheque falsificado para obtener bienes constituye un delito de estafa según el Código Penal colombiano.
# 🔎 Buscando documentos: delito de estafa por uso de cheque falso Código Penal Ley 599 de 2000 ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 41 ...
# 📋 Agregando fuentes al contexto ...
# 📋 25 fuentes agregadas ...
# 🤖 Generando nuevas búsquedas con la nueva información ...
# 💰 Conversation price: $448.719375 COP (In: 694573, Out: 8763, Total token: 703336)
#    This message: $16.53858 COP (In: 26308, Out: 146, Total token: 26454)
# 🤖 3 búsquedas generadas ...
# Buscando 'falsificación de documentos Código Penal Ley 599 de 2000': Necesito entender cómo se tipifica la falsificación de documentos, específicamente cheques, en el Código Penal colombiano para determinar el delito cometido.
# 🔎 Buscando documentos: falsificación de documentos Código Penal Ley 599 de 2000 ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 38 ...
# Buscando 'uso de documento falso Código Penal Ley 599 de 2000': Es importante saber si el uso de un cheque falsificado para obtener bienes constituye un delito adicional al de falsificación.
# 🔎 Buscando documentos: uso de documento falso Código Penal Ley 599 de 2000 ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 34 ...
# Buscando 'delito de estafa Código Penal Ley 599 de 2000': Quiero verificar si el uso de un cheque falsificado para adquirir un bien puede ser considerado como estafa bajo el Código Penal colombiano.
# 🔎 Buscando documentos: delito de estafa Código Penal Ley 599 de 2000 ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 47 ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 125 pasaron 77 ...
# 📋 Agregando fuentes al contexto ...
# 📋 77 fuentes agregadas ...
# 🤖 Escogiendo las mejores fuentes para responder al usuario ...
# 💰 Conversation price: $473.960205 COP (In: 734335, Out: 9083, Total token: 743418)
#    This message: $25.24083 COP (In: 39762, Out: 320, Total token: 40082)
# 1.[20240814181609ley599de2000pdf_chunk199]: Este artículo del Código Penal colombiano aborda la falsedad en documentos, lo cual es relevante para el caso de falsificación de un cheque.
# 2.[20240814181609ley599de2000pdf_chunk246]: Este artículo del Código Penal colombiano define el delito de estafa, que es relevante para el uso de un cheque falsificado para obtener un bien.
# 3.[20240814181609ley599de2000pdf_chunk201]: Este artículo del Código Penal colombiano trata sobre el uso de documento falso, lo cual es aplicable al uso de un cheque falsificado.
# 4.[20240825145230csjsp3052830102008pdf_chunk4]: Esta fuente de jurisprudencia aborda la aplicación de la ley en casos de falsedad y estafa, proporcionando contexto sobre cómo se interpretan estos delitos.
# 5.[20240825102416csjsentencia2824326092007pdf_chunk3]: Esta fuente de jurisprudencia discute la falsedad en documento privado y fraude procesal, lo cual es relevante para entender la aplicación de la ley en casos de falsificación de cheques.
# 📋 Agregando fuentes al contexto ...
# 📋 4 fuentes agregadas ...
# 💰 Conversation price: $15691.520000000002 COP (In: 737306, Out: 9378, Total token: 746684)
#    This message: $79.048 COP (In: 2971, Out: 295, Total token: 3266)
# <p>En el caso de que A falsifique un cheque y lo utilice para comprar un televisor a B, se estarían cometiendo varios delitos según el Código Penal colombiano:</p>
#
# <ul>
#     <li><strong>Falsedad Material en Documento Público:</strong> Si el cheque es considerado un documento público, A estaría cometiendo el delito de falsedad material en documento público, lo cual se sanciona con prisión de cuarenta y ocho (48) a ciento ocho (108) meses [20240814181609ley599de2000pdf_chunk199].</li>
#     <li><strong>Uso de Documento Falso:</strong> Al utilizar el cheque falsificado, A estaría cometiendo el delito de uso de documento falso, que se castiga con prisión de cuatro (4) a doce (12) años [20240814181609ley599de2000pdf_chunk201].</li>
#     <li><strong>Estafa:</strong> Al engañar a B para obtener el televisor mediante un cheque falsificado, A también podría estar cometiendo el delito de estafa, que implica obtener un beneficio económico mediante engaño [20240825145230csjsp3052830102008pdf_chunk4].</li>
# </ul>
#
# <p>Estos delitos pueden ser acumulativos, y la pena se determinaría considerando la gravedad de cada uno de ellos y las circunstancias del caso.</p>
#
#
# <p>1. Ley 599 de 2000 - Página 112<br>
# 3. Ley 599 de 2000 - Página 113<br>
# 4. CSJ - SP30528(30-10-2008) - Página 5<br>
# 5. CSJ - Sentencia 28243(26-09-2007) - Página 4<br>
# </p>
# 🙎‍♂️ User: ¿Cuáles son las formas de autoría en derecho penal?
# 🤖 Generando queries con la pregunta del usuario ...
# 💰 Conversation price: $477.45401999999996 COP (In: 738656, Out: 9423, Total token: 748079)
#    This message: $0.94095 COP (In: 1350, Out: 45, Total token: 1395)
# 🤖 1 búsquedas generadas ...
# Necesito identificar y entender las diferentes formas de autoría reconocidas en el derecho penal para proporcionar una respuesta completa y precisa.
# 🔎 Buscando documentos: formas de autoría en derecho penal ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 45 ...
# 📋 Agregando fuentes al contexto ...
# 📋 25 fuentes agregadas ...
# 🤖 Generando nuevas búsquedas con la nueva información ...
# 💰 Conversation price: $486.53265 COP (In: 752778, Out: 9583, Total token: 762361)
#    This message: $9.07863 COP (In: 14122, Out: 160, Total token: 14282)
# 🤖 3 búsquedas generadas ...
# Buscando 'autoría directa, autoría mediata, coautoría en derecho penal': Esta búsqueda me ayudará a identificar y entender las formas específicas de autoría reconocidas en el derecho penal, como la autoría directa, mediata y la coautoría.
# 🔎 Buscando documentos: autoría directa, autoría mediata, coautoría en derecho penal ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 50 ...
# Buscando 'diferencias entre autoría y participación en derecho penal': Es importante distinguir entre las formas de autoría y las de participación para comprender cómo se categorizan las acciones de los individuos en un delito.
# 🔎 Buscando documentos: diferencias entre autoría y participación en derecho penal ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 16 ...
# Buscando 'teoría del dominio del hecho en derecho penal': La teoría del dominio del hecho es fundamental para entender cómo se determina la autoría en el derecho penal, especialmente en casos de autoría mediata y coautoría.
# 🔎 Buscando documentos: teoría del dominio del hecho en derecho penal ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 27 ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 91 pasaron 79 ...
# 📋 Agregando fuentes al contexto ...
# 📋 79 fuentes agregadas ...
# 🤖 Escogiendo las mejores fuentes para responder al usuario ...
# 💰 Conversation price: $512.76486 COP (In: 794072, Out: 9923, Total token: 803995)
#    This message: $26.232210000000002 COP (In: 41294, Out: 340, Total token: 41634)
# 1.[20240825150044csjsp1167202257957pdf_chunk19]: Esta fuente menciona las formas de autoría en el Código Penal colombiano, incluyendo la autoría directa, mediata y la coautoría, lo cual es central para responder la pregunta.
# 2.[20240822234615ccc6742017pdf_chunk867]: Proporciona una descripción de las formas de autoría y participación en el Código Penal, incluyendo la autoría mediata y la coautoría, lo cual es relevante para la consulta.
# 3.[20240813150014dialogospunitivosderechopenalcorporativo2019pdf_chunk270]: Explica la teoría del dominio del hecho, que es fundamental para entender las formas de autoría en el derecho penal.
# 4.[20240825104556csjsentencia2878005122007pdf_chunk24]: Distingue entre autoría y participación, y explica las diferencias entre autor directo, mediato y coautor, lo cual es esencial para la consulta.
# 5.[20240813145138fernandezcarrasquillajdpteoriadeldelitoypenavolll2012pdf_chunk133]: Ofrece una perspectiva doctrinal sobre la relación entre autoría y participación, lo cual complementa la información sobre las formas de autoría.
# 📋 Agregando fuentes al contexto ...
# 📋 5 fuentes agregadas ...
# 💰 Conversation price: $16979.8835 COP (In: 797486, Out: 10267, Total token: 807753)
#    This message: $91.14300000000001 COP (In: 3414, Out: 344, Total token: 3758)
# <p>En el derecho penal colombiano, las formas de autoría se encuentran reguladas principalmente en los artículos 29 y 30 del Código Penal. Estas formas de autoría son:</p>
#
# <ul>
#     <li><strong>Autoría Directa:</strong> Es cuando una persona realiza la conducta punible por sí misma.</li>
#     <li><strong>Autoría Mediata:</strong> Se refiere a quien realiza la conducta punible utilizando a otra persona como instrumento. En este caso, el autor mediato tiene el dominio de la voluntad de la persona que actúa como instrumento [20240825104556csjsentencia2878005122007pdf_chunk24].</li>
#     <li><strong>Coautoría:</strong> Implica que dos o más personas actúan conjuntamente en la realización de la conducta punible, mediando un acuerdo común y una división de trabajo criminal [20240822234615ccc6742017pdf_chunk867].</li>
# </ul>
#
# <p>Estas formas de autoría se distinguen de las formas de participación, como la determinación (o instigación) y la complicidad, que implican diferentes grados de intervención en la ejecución de la conducta punible [20240825150044csjsp1167202257957pdf_chunk19].</p>
#
# <p>La teoría del dominio del hecho es fundamental para entender estas formas de autoría, ya que se centra en el control que el autor tiene sobre la realización del delito, ya sea de manera directa, mediata o en colaboración con otros [20240813150014dialogospunitivosderechopenalcorporativo2019pdf_chunk270].</p>
#
#
# <p>1. CSJ - SP1167-2022(57957) - Página 20<br>
# 2. CC - C674-2017 - Página 374<br>
# 3. DIÁLOGOS PUNITIVOS -  Derecho penal corporativo- 2019 - Página 196<br>
# 4. CSJ - Sentencia 28780(05-12-2007) - Página 24<br>
# 5. FERNANDEZ CARRASQUILLA, J - DP teoria del delito y pena Vol ll. 2012 - Página 77<br>
# </p>
# 🙎‍♂️ User: ¿Cuándo se consuma el hurto?
# 🤖 Generando queries con la pregunta del usuario ...
# 💰 Conversation price: $516.6571949999999 COP (In: 798833, Out: 10315, Total token: 809148)
#    This message: $0.9464849999999999 COP (In: 1347, Out: 48, Total token: 1395)
# 🤖 1 búsquedas generadas ...
# Necesito entender el momento exacto en que se considera consumado el delito de hurto según la legislación o doctrina legal.
# 🔎 Buscando documentos: ¿cuándo se consuma el hurto? ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 41 ...
# 📋 Agregando fuentes al contexto ...
# 📋 25 fuentes agregadas ...
# 🤖 Generando nuevas búsquedas con la nueva información ...
# 💰 Conversation price: $525.614055 COP (In: 812849, Out: 10452, Total token: 823301)
#    This message: $8.95686 COP (In: 14016, Out: 137, Total token: 14153)
# 🤖 3 búsquedas generadas ...
# Buscando 'consumación del hurto Código Penal Ley 599 de 2000': Buscar en el Código Penal colombiano el momento exacto de consumación del hurto según la ley vigente.
# 🔎 Buscando documentos: consumación del hurto Código Penal Ley 599 de 2000 ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 40 ...
# Buscando 'teoría de la disponibilidad hurto': Explorar la teoría de la disponibilidad, que es una de las teorías más mencionadas sobre la consumación del hurto.
# 🔎 Buscando documentos: teoría de la disponibilidad hurto ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 19 ...
# Buscando 'jurisprudencia Corte Suprema de Justicia sobre consumación del hurto': Revisar decisiones de la Corte Suprema de Justicia para entender cómo se ha interpretado la consumación del hurto en casos específicos.
# 🔎 Buscando documentos: jurisprudencia Corte Suprema de Justicia sobre consumación del hurto ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 49 ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 94 pasaron 79 ...
# 📋 Agregando fuentes al contexto ...
# 📋 79 fuentes agregadas ...
# 🤖 Escogiendo las mejores fuentes para responder al usuario ...
# 💰 Conversation price: $551.580585 COP (In: 853727, Out: 10788, Total token: 864515)
#    This message: $25.966529999999995 COP (In: 40878, Out: 336, Total token: 41214)
# 1.[20240826145418csjsp3601914032011pdf_chunk6]: Explica que el hurto se consuma cuando el bien es extraído de la esfera de custodia del dueño, poseedor o tenedor, con la intención de lucro, sin necesidad de materializar la ganancia.
# 2.[20240813150354universidadexternadoleccionesdederechopenalparteespecialvol12011pdf_chunk1096]: Describe la teoría de la disponibilidad, que es clave para entender el momento consumativo del hurto.
# 3.[20240821001640pgnhurtomomentoconsumativopdf_chunk18]: Detalla que el hurto se consuma cuando el delincuente asume el poder sobre el bien y la víctima pierde la posibilidad de protegerlo.
# 4.[20240821001640pgnhurtomomentoconsumativopdf_chunk19]: Explica que el apoderamiento no está condicionado por circunstancias modales, temporales o locales, y se consuma cuando el objeto sale de la órbita de dominio del tenedor.
# 5.[20240821070752pgnhurtodefinicionpdf_chunk14]: Reitera que el hurto se consuma cuando el bien es sacado de la esfera de dominio de la víctima para incorporarlo a la del autor.
# 📋 Agregando fuentes al contexto ...
# 📋 5 fuentes agregadas ...
# 💰 Conversation price: $18254.471 COP (In: 857192, Out: 11090, Total token: 868282)
#    This message: $89.60549999999999 COP (In: 3465, Out: 302, Total token: 3767)
# <p>El hurto se consuma cuando el bien es extraído de la esfera de custodia del dueño, poseedor o tenedor, con la intención de lucro, sin necesidad de materializar la ganancia. Esto significa que el momento consumativo del delito se produce cuando el sujeto activo de la conducta extrae el bien de la esfera de custodia de su dueño, poseedor o tenedor, con la intención de lucro [20240826145418csjsp3601914032011pdf_chunk6].</p>
#
# <p>La teoría de la disponibilidad también es relevante para entender el momento consumativo del hurto. Según esta teoría, el delito se consuma cuando el sujeto activo obtiene la posibilidad inmediata de realizar actos dispositivos sobre la cosa, posibilidad de la que carecía antes de la acción porque la cosa estaba en poder de otra persona [20240813150354universidadexternadoleccionesdederechopenalparteespecialvol12011pdf_chunk1096].</p>
#
# <p>Además, el hurto se consuma cuando el delincuente asume el poder sobre el bien y la víctima pierde la posibilidad de protegerlo. Esto ocurre cuando el objeto sale de la órbita de dominio del tenedor y se tiene algún grado de disposición jurídica sobre el mismo [20240821001640pgnhurtomomentoconsumativopdf_chunk18] [20240821001640pgnhurtomomentoconsumativopdf_chunk19].</p>
#
#
# <p>1. CSJ - SP36019(14-03-2011) - Página 7<br>
# 2. UNIVERSIDAD EXTERNADO - Lecciones de Derecho penal - parte especial vol 1 -2011 - Página 948<br>
# 3. PGN - HURTO - Momento consumativo - Página 13<br>
# 4. PGN - HURTO - Momento consumativo - Página 14<br>
# 5. PGN - HURTO - Definicion - Página 9<br>
# </p>
# 🙎‍♂️ User: ¿Se puede archivar una investigación cuando se encuentra que el procesado actuó en legítima defensa?
# 🤖 Generando queries con la pregunta del usuario ...
# 💰 Conversation price: $555.4274099999999 COP (In: 858550, Out: 11146, Total token: 869696)
#    This message: $0.97293 COP (In: 1358, Out: 56, Total token: 1414)
# 🤖 1 búsquedas generadas ...
# Necesito entender si la figura de la legítima defensa permite el archivo de una investigación penal, lo cual implica conocer las condiciones legales y procesales para que esto ocurra.
# 🔎 Buscando documentos: legítima defensa archivo de investigación penal ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 48 ...
# 📋 Agregando fuentes al contexto ...
# 📋 25 fuentes agregadas ...
# 🤖 Generando nuevas búsquedas con la nueva información ...
# 💰 Conversation price: $564.520185 COP (In: 872667, Out: 11313, Total token: 883980)
#    This message: $9.092774999999998 COP (In: 14117, Out: 167, Total token: 14284)
# 🤖 3 búsquedas generadas ...
# Buscando 'legítima defensa archivo de investigación penal Colombia': Necesito entender si la figura de la legítima defensa permite el archivo de una investigación penal en Colombia, lo cual implica conocer las condiciones legales y procesales para que esto ocurra.
# 🔎 Buscando documentos: legítima defensa archivo de investigación penal Colombia ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 37 ...
# Buscando 'artículo 332 Ley 906 de 2004 archivo de investigación': El artículo 332 de la Ley 906 de 2004 podría contener disposiciones sobre el archivo de investigaciones penales, por lo que es relevante verificar su contenido en relación con la legítima defensa.
# 🔎 Buscando documentos: artículo 332 Ley 906 de 2004 archivo de investigación ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 43 ...
# Buscando 'jurisprudencia archivo de investigación por legítima defensa': Buscar jurisprudencia específica sobre casos donde se haya archivado una investigación por legítima defensa puede proporcionar ejemplos prácticos y decisiones judiciales relevantes.
# 🔎 Buscando documentos: jurisprudencia archivo de investigación por legítima defensa ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 40 ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 100 pasaron 80 ...
# 📋 Agregando fuentes al contexto ...
# 📋 80 fuentes agregadas ...
# 🤖 Escogiendo las mejores fuentes para responder al usuario ...
# 💰 Conversation price: $590.502705 COP (In: 913431, Out: 11684, Total token: 925115)
#    This message: $25.982519999999997 COP (In: 40764, Out: 371, Total token: 41135)
# 1.[20240820085329ley906de2004pdf_chunk197]: Este fragmento de la Ley 906 de 2004 menciona las causales para solicitar la preclusión, incluyendo la existencia de una causal que excluya la responsabilidad, como la legítima defensa.
# 2.[20240820085329ley906de2004pdf_chunk91]: Este fragmento de la Ley 906 de 2004 menciona el archivo de la indagación y la posibilidad de reapertura, lo cual es relevante para entender el proceso de archivo en casos de legítima defensa.
# 3.[20240820085329ley906de2004pdf_chunk42]: Este fragmento de la Ley 906 de 2004 explica el archivo de las diligencias cuando no existen motivos para caracterizar un hecho como delito, lo cual puede aplicarse en casos de legítima defensa.
# 4.[20240825202545csjsp3128008072009pdf_chunk8]: Este fragmento de jurisprudencia de la Corte Suprema de Justicia menciona la posibilidad de invocar la legítima defensa para solicitar la preclusión, lo cual es relevante para el archivo de la investigación.
# 5.[20240819085720cesec3exp1998n10817pdf_chunk14]: Este fragmento de jurisprudencia del Consejo de Estado discute la legítima defensa como causal de justificación, lo cual es relevante para el archivo de investigaciones.
# 📋 Agregando fuentes al contexto ...
# 📋 5 fuentes agregadas ...
# 💰 Conversation price: $19529.591500000002 COP (In: 916837, Out: 11942, Total token: 928779)
#    This message: $85.69000000000001 COP (In: 3406, Out: 258, Total token: 3664)
# <p>En el contexto del sistema penal colombiano, es posible archivar una investigación cuando se determina que el procesado actuó en legítima defensa. Según la Ley 906 de 2004, el fiscal puede solicitar la preclusión del caso si existe una causal que excluya la responsabilidad, como la legítima defensa, de acuerdo con el Código Penal [20240820085329ley906de2004pdf_chunk197].</p>
#
# <p>El archivo de las diligencias puede ocurrir cuando la Fiscalía constata que no existen motivos o circunstancias fácticas que permitan caracterizar el hecho como delito, lo cual puede incluir situaciones de legítima defensa [20240820085329ley906de2004pdf_chunk42].</p>
#
# <p>Además, la jurisprudencia de la Corte Suprema de Justicia respalda la posibilidad de invocar la legítima defensa para solicitar la preclusión, lo que es relevante para el archivo de la investigación [20240825202545csjsp3128008072009pdf_chunk8].</p>
#
# <p>Por lo tanto, si se demuestra que el procesado actuó en legítima defensa, el fiscal puede solicitar al juez la preclusión del caso, lo que llevaría al archivo de la investigación.</p>
#
#
# <p>1. Ley 906 de 2004 - Página 98<br>
# 2. Ley 906 de 2004 - Página 47<br>
# 3. Ley 906 de 2004 - Página 22<br>
# 4. CSJ - SP31280(08-07-2009) - Página 9<br>
# 5. CE-SEC3-EXP1998-N10817 - Página 11<br>
# </p>
# 🙎‍♂️ User: ¿Se puede precluir una investigación antes de formular imputación?
# 🤖 Generando queries con la pregunta del usuario ...
# 💰 Conversation price: $594.246825 COP (In: 918187, Out: 12017, Total token: 930204)
#    This message: $1.01475 COP (In: 1350, Out: 75, Total token: 1425)
# 🤖 1 búsquedas generadas ...
# Necesito entender si el Código de Procedimiento Penal colombiano permite la preclusión de una investigación antes de la formulación de imputación, ya que este código regula el proceso penal en Colombia.
# 🔎 Buscando documentos: preclusión de investigación antes de imputación en el Código de Procedimiento Penal Ley 906 de 2004 ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 42 ...
# 📋 Agregando fuentes al contexto ...
# 📋 25 fuentes agregadas ...
# 🤖 Generando nuevas búsquedas con la nueva información ...
# 💰 Conversation price: $602.919555 COP (In: 931629, Out: 12182, Total token: 943811)
#    This message: $8.67273 COP (In: 13442, Out: 165, Total token: 13607)
# 🤖 3 búsquedas generadas ...
# Buscando 'preclusión antes de imputación Código de Procedimiento Penal Ley 906 de 2004': Necesito confirmar si el Código de Procedimiento Penal permite la preclusión antes de la imputación, ya que este código regula el proceso penal en Colombia.
# 🔎 Buscando documentos: preclusión antes de imputación Código de Procedimiento Penal Ley 906 de 2004 ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 45 ...
# Buscando 'artículo 331 Ley 906 de 2004': El artículo 331 del Código de Procedimiento Penal menciona la preclusión, y es importante verificar su contenido exacto para entender en qué momento procesal se puede solicitar.
# 🔎 Buscando documentos: artículo 331 Ley 906 de 2004 ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 46 ...
# Buscando 'jurisprudencia sobre preclusión antes de imputación en Colombia': Buscar jurisprudencia relevante puede proporcionar interpretaciones y aplicaciones prácticas de la ley respecto a la preclusión antes de la imputación.
# 🔎 Buscando documentos: jurisprudencia sobre preclusión antes de imputación en Colombia ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 39 ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 100 pasaron 81 ...
# 📋 Agregando fuentes al contexto ...
# 📋 81 fuentes agregadas ...
# 🤖 Escogiendo las mejores fuentes para responder al usuario ...
# 💰 Conversation price: $628.49064 COP (In: 971980, Out: 12489, Total token: 984469)
#    This message: $25.571084999999997 COP (In: 40351, Out: 307, Total token: 40658)
# 1.[20240820085329ley906de2004pdf_chunk42]: Este fragmento de la Ley 906 de 2004 menciona que la Fiscalía puede decretar la extinción de la acción penal antes de la imputación, lo cual es relevante para la preclusión antes de la imputación.
# 2.[20240813161442tsdjcalisp760016000193202105228002022pdf_chunk12]: Este documento de jurisprudencia del Tribunal de Cali aclara que la preclusión puede solicitarse antes de la imputación, según la interpretación de la Corte Constitucional.
# 3.[20240820101138tsdjmanizalessp201200179000pdf_chunk11]: Este documento de jurisprudencia del Tribunal de Manizales explica las oportunidades procesales para solicitar la preclusión, incluyendo antes de la imputación.
# 4.[20240813151048csjspl1100102300002011000560009062011pdf_chunk5]: La Corte Suprema de Justicia detalla que la preclusión puede ser solicitada en cualquier etapa, incluso antes de la imputación, si no hay mérito para acusar.
# 📋 Agregando fuentes al contexto ...
# 📋 4 fuentes agregadas ...
# 💰 Conversation price: $20770.702500000003 COP (In: 974907, Out: 12766, Total token: 987673)
#    This message: $77.039 COP (In: 2927, Out: 277, Total token: 3204)
# <p>En el sistema penal colombiano, es posible solicitar la preclusión de una investigación antes de formular la imputación. Según el artículo 78 de la Ley 906 de 2004, la Fiscalía puede decretar la extinción de la acción penal antes de la imputación si se presenta una causal que lo justifique, y puede ordenar el archivo de la actuación [20240820085329ley906de2004pdf_chunk42].</p>
#
# <p>Además, la jurisprudencia ha respaldado esta posibilidad. La Corte Constitucional, en la Sentencia C-591 de 2005, ha interpretado que la preclusión puede solicitarse durante la fase de indagación, es decir, antes de la imputación [20240813161442tsdjcalisp760016000193202105228002022pdf_chunk12].</p>
#
# <p>La Corte Suprema de Justicia también ha señalado que la preclusión puede ser solicitada en cualquier etapa de la actuación, incluso antes de la imputación, si no hay mérito para acusar [20240813151048csjspl1100102300002011000560009062011pdf_chunk5].</p>
#
# <p>Por lo tanto, sí es posible precluir una investigación antes de formular imputación, siempre que se cumplan las causales previstas en la ley.</p>
#
#
# <p>1. Ley 906 de 2004 - Página 22<br>
# 2. TSDJ CALI - SP76001 60 00 193 2021 05228 00 - 2022 - Página 11<br>
# 3. TSDJ Manizales - SP2012-001790-00 - Página 10<br>
# 4. CSJ - SPL1100102300002011-00056-00 (09-06-2011) - Página 6<br>
# </p>
# 🙎‍♂️ User: ¿Cuáles son las causales genéricas de atenuación punitiva?
# 🤖 Generando queries con la pregunta del usuario ...
# 💰 Conversation price: $631.9844549999999 COP (In: 976261, Out: 12839, Total token: 989100)
#    This message: $1.01229 COP (In: 1354, Out: 73, Total token: 1427)
# 🤖 1 búsquedas generadas ...
# Necesito buscar las causales genéricas de atenuación punitiva en el Código Penal colombiano, ya que es el documento legal que regula las penas y sus atenuantes en Colombia.
# 🔎 Buscando documentos: causales genéricas de atenuación punitiva Código Penal Ley 599 de 2000 ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 38 ...
# 📋 Agregando fuentes al contexto ...
# 📋 25 fuentes agregadas ...
# 🤖 Generando nuevas búsquedas con la nueva información ...
# 💰 Conversation price: $640.853985 COP (In: 990011, Out: 13007, Total token: 1003018)
#    This message: $8.86953 COP (In: 13750, Out: 168, Total token: 13918)
# 🤖 3 búsquedas generadas ...
# Buscando 'artículo 55 Código Penal Ley 599 de 2000': El artículo 55 del Código Penal colombiano menciona las circunstancias de menor punibilidad, que son relevantes para entender las causales genéricas de atenuación punitiva.
# 🔎 Buscando documentos: artículo 55 Código Penal Ley 599 de 2000 ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 46 ...
# Buscando 'artículo 61 Código Penal Ley 599 de 2000': El artículo 61 del Código Penal establece los fundamentos para la individualización de la pena, incluyendo cómo se aplican las circunstancias de atenuación punitiva.
# 🔎 Buscando documentos: artículo 61 Código Penal Ley 599 de 2000 ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 44 ...
# Buscando 'jurisprudencia sobre causales genéricas de atenuación punitiva': Buscar jurisprudencia específica puede proporcionar ejemplos y aclaraciones sobre cómo se aplican las causales genéricas de atenuación punitiva en casos reales.
# 🔎 Buscando documentos: jurisprudencia sobre causales genéricas de atenuación punitiva ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 46 ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 100 pasaron 71 ...
# 📋 Agregando fuentes al contexto ...
# 📋 71 fuentes agregadas ...
# 🤖 Escogiendo las mejores fuentes para responder al usuario ...
# 💰 Conversation price: $663.9755250000001 COP (In: 1026275, Out: 13340, Total token: 1039615)
#    This message: $23.12154 COP (In: 36264, Out: 333, Total token: 36597)
# 1.[20240814181609ley599de2000pdf_chunk42]: El artículo 55 del Código Penal colombiano establece las circunstancias de menor punibilidad, que son relevantes para entender las causales genéricas de atenuación punitiva.
# 2.[20240814181609ley599de2000pdf_chunk47]: El artículo 61 del Código Penal colombiano establece los fundamentos para la individualización de la pena, incluyendo cómo se aplican las circunstancias de atenuación punitiva.
# 3.[20240823184234csjsp1086804042001pdf_chunk46]: Esta fuente de jurisprudencia menciona las causales genéricas de atenuación y agravación punitivas, proporcionando contexto sobre su aplicación.
# 4.[20240813154821tsdjcalisp7600160001932018219492022pdf_chunk82]: Esta fuente de jurisprudencia explica cómo se aplica la dosificación punitiva en relación con las circunstancias de atenuación y agravación punitiva.
# 5.[20240826100841csjsentencia3818408022012pdf_chunk12]: Esta fuente de jurisprudencia aclara que las circunstancias de menor punibilidad no modifican los límites de la sanción penal, pero influyen en la determinación de la pena.
# 📋 Agregando fuentes al contexto ...
# 📋 5 fuentes agregadas ...
# 💰 Conversation price: $21951.974000000006 COP (In: 1029641, Out: 13729, Total token: 1043370)
#    This message: $92.9265 COP (In: 3366, Out: 389, Total token: 3755)
# <p>Las causales genéricas de atenuación punitiva en el Código Penal colombiano están establecidas en el artículo 55 de la Ley 599 de 2000. Estas circunstancias de menor punibilidad son:</p>
#
# <ol>
#     <li>La carencia de antecedentes penales.</li>
#     <li>El obrar por motivos nobles o altruistas.</li>
#     <li>El obrar en estado de emoción, pasión excusables, o de temor intenso.</li>
#     <li>La influencia de apremiantes circunstancias personales o familiares en la ejecución de la conducta punible.</li>
#     <li>Procurar voluntariamente después de cometida la conducta, anular o disminuir sus consecuencias.</li>
#     <li>Reparar voluntariamente el daño ocasionado aunque no sea en forma total. Así mismo, si se ha procedido a indemnizar a las personas afectadas con el hecho punible.</li>
#     <li>Presentarse voluntariamente a las autoridades después de haber cometido la conducta punible o evitar la injusta sindicación de terceros.</li>
#     <li>La indigencia o la falta de ilustración, en cuanto hayan influido en la ejecución de la conducta punible.</li>
#     <li>Las condiciones de inferioridad psíquica determinadas por la edad o por circunstancias orgánicas, en cuanto hayan influido en la ejecución de la conducta punible.</li>
#     <li>Cualquier circunstancia de análoga significación a las anteriores.</li>
# </ol>
#
# <p>Estas circunstancias no modifican los límites de la sanción penal, pero influyen en la determinación de la pena dentro del marco legal establecido [20240814181609ley599de2000pdf_chunk42] [20240826100841csjsentencia3818408022012pdf_chunk12].</p>
#
#
# <p>1. Ley 599 de 2000 - Página 25<br>
# 2. Ley 599 de 2000 - Página 28<br>
# 3. CSJ - SP10868(04-04-2001) - Página 38<br>
# 4. TSDJ CALI - SP76001 60 00 193 2018 21949 - 2022 - Página 58<br>
# 5. CSJ - Sentencia 38184(08-02-2012) - Página 12<br>
# </p>
# 🙎‍♂️ User: ¿Qué se entiende por “documento” en el derecho penal?
# 🤖 Generando queries con la pregunta del usuario ...
# 💰 Conversation price: $667.94658 COP (In: 1030992, Out: 13775, Total token: 1044767)
#    This message: $0.9440249999999999 COP (In: 1351, Out: 46, Total token: 1397)
# 🤖 1 búsquedas generadas ...
# Necesito entender cómo se define un 'documento' específicamente en el contexto del derecho penal para proporcionar una respuesta precisa.
# 🔎 Buscando documentos: definición de documento en el derecho penal ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 22 ...
# 📋 Agregando fuentes al contexto ...
# 📋 22 fuentes agregadas ...
# 🤖 Generando nuevas búsquedas con la nueva información ...
# 💰 Conversation price: $675.9594149999999 COP (In: 1043413, Out: 13927, Total token: 1057340)
#    This message: $8.012834999999999 COP (In: 12421, Out: 152, Total token: 12573)
# 🤖 3 búsquedas generadas ...
# Buscando 'definición de documento en el derecho penal colombiano': Necesito una definición clara y específica de lo que se considera un documento en el derecho penal colombiano para entender su alcance y aplicación.
# 🔎 Buscando documentos: definición de documento en el derecho penal colombiano ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 26 ...
# Buscando 'artículo 294 Código Penal Ley 599 de 2000 definición de documento': El artículo 294 del Código Penal colombiano es relevante para la definición de documento en el contexto penal, por lo que es crucial revisar su contenido exacto.
# 🔎 Buscando documentos: artículo 294 Código Penal Ley 599 de 2000 definición de documento ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 40 ...
# Buscando 'documento electrónico en el derecho penal': Dado que los documentos electrónicos son cada vez más comunes, es importante entender cómo se consideran en el derecho penal y si tienen el mismo valor probatorio que los documentos tradicionales.
# 🔎 Buscando documentos: documento electrónico en el derecho penal ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 21 ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 93 pasaron 79 ...
# 📋 Agregando fuentes al contexto ...
# 📋 79 fuentes agregadas ...
# 🤖 Escogiendo las mejores fuentes para responder al usuario ...
# 💰 Conversation price: $701.9234849999999 COP (In: 1084339, Out: 14250, Total token: 1098589)
#    This message: $25.96407 COP (In: 40926, Out: 323, Total token: 41249)
# 1.[20240814181609ley599de2000pdf_chunk202]: Esta fuente proporciona la definición de "documento" en el contexto del derecho penal según el artículo 294 del Código Penal colombiano, que es crucial para entender el término en este ámbito.
# 2.[20240813133453ccc3562003pdf_chunk1]: Esta fuente también cita el artículo 294 del Código Penal, proporcionando contexto adicional sobre su interpretación y aplicación en el derecho penal.
# 3.[20240813150814castrocuencamanualdederechopenalparteespecialtomoii2019pdf_chunk1142]: Esta fuente ofrece una perspectiva doctrinal sobre la definición de documento en el derecho penal, complementando la definición legal con interpretaciones académicas.
# 4.[20240813133453ccc3562003pdf_chunk7]: Esta fuente discute la inclusión de documentos electrónicos en la definición de documento penal, lo cual es relevante para entender su aplicación en el contexto moderno.
# 5.[20240813175028tsdjmanizalessp20100000302lpdf_chunk133]: Esta fuente proporciona una interpretación jurisprudencial sobre la definición de documento en el derecho penal, lo que ayuda a entender cómo se aplica en la práctica judicial.
# 📋 Agregando fuentes al contexto ...
# 📋 5 fuentes agregadas ...
# 💰 Conversation price: $23188.411 COP (In: 1087696, Out: 14482, Total token: 1102178)
#    This message: $83.0865 COP (In: 3357, Out: 232, Total token: 3589)
# <p>En el derecho penal colombiano, el término "documento" se define en el artículo 294 del Código Penal. Según esta disposición, se considera documento "toda expresión de persona conocida o conocible recogida por escrito o por cualquier medio mecánico o técnicamente impreso, soporte material que exprese o incorpore datos o hechos, que tengan capacidad probatoria" [20240814181609ley599de2000pdf_chunk202].</p>
#
# <p>Esta definición incluye tanto documentos tradicionales en papel como documentos electrónicos, ya que el término "soporte material" abarca cualquier medio que pueda expresar o incorporar datos o hechos con capacidad probatoria [20240813133453ccc3562003pdf_chunk7].</p>
#
# <p>Desde una perspectiva doctrinal, se enfatiza que un documento debe tener la capacidad de probar situaciones con relevancia jurídica. Esto implica que, además de ser una expresión escrita o impresa, debe tener una función probatoria [20240813150814castrocuencamanualdederechopenalparteespecialtomoii2019pdf_chunk1142].</p>
#
#
# <p>1. Ley 599 de 2000 - Página 113<br>
# 2. CC - C356-2003 - Página 2<br>
# 3. CASTRO CUENCA - Manual de Derecho penal Parte Especial - Tomo II - 2019 - Página 305<br>
# 4. CC - C356-2003 - Página 6<br>
# 5. TSDJ Manizales - SP2010-00003-02 L - Página 80<br>
# </p>
# 🙎‍♂️ User: ¿Cuáles son las causales de agravación de la estafa?
# 🤖 Generando queries con la pregunta del usuario ...
# 💰 Conversation price: $705.5550599999999 COP (In: 1089048, Out: 14549, Total token: 1103597)
#    This message: $0.9963 COP (In: 1352, Out: 67, Total token: 1419)
# 🤖 1 búsquedas generadas ...
# Necesito buscar las causales específicas de agravación de la estafa en el Código Penal colombiano, ya que es la fuente legal que regula este delito y sus agravantes.
# 🔎 Buscando documentos: causales de agravación de la estafa Código Penal Ley 599 de 2000 ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 38 ...
# 📋 Agregando fuentes al contexto ...
# 📋 25 fuentes agregadas ...
# 🤖 Generando nuevas búsquedas con la nueva información ...
# 💰 Conversation price: $714.3304949999999 COP (In: 1102665, Out: 14712, Total token: 1117377)
#    This message: $8.775434999999998 COP (In: 13617, Out: 163, Total token: 13780)
# 🤖 3 búsquedas generadas ...
# Buscando 'artículo 267 Código Penal Ley 599 de 2000': Este artículo del Código Penal colombiano detalla las circunstancias específicas de agravación para el delito de estafa, lo cual es crucial para responder a la pregunta del usuario.
# 🔎 Buscando documentos: artículo 267 Código Penal Ley 599 de 2000 ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 42 ...
# Buscando 'jurisprudencia sobre agravación de la estafa en Colombia': Buscar jurisprudencia relevante puede proporcionar interpretaciones judiciales y ejemplos prácticos sobre cómo se aplican las causales de agravación de la estafa en casos reales.
# 🔎 Buscando documentos: jurisprudencia sobre agravación de la estafa en Colombia ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 37 ...
# Buscando 'doctrina sobre agravación de la estafa en Colombia': Consultar doctrina puede ofrecer un análisis más profundo y teórico sobre las causales de agravación de la estafa, complementando la información legal y jurisprudencial.
# 🔎 Buscando documentos: doctrina sobre agravación de la estafa en Colombia ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 38 ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 100 pasaron 75 ...
# 📋 Agregando fuentes al contexto ...
# 📋 75 fuentes agregadas ...
# 🤖 Escogiendo las mejores fuentes para responder al usuario ...
# 💰 Conversation price: $738.4643249999999 COP (In: 1141035, Out: 14930, Total token: 1155965)
#    This message: $24.13383 COP (In: 38370, Out: 218, Total token: 38588)
# 1.[20240814181609ley599de2000pdf_chunk183]: Este artículo del Código Penal colombiano detalla las circunstancias específicas de agravación para el delito de estafa, lo cual es crucial para responder a la pregunta del usuario.
# 2.[20240825120633csjsp2853807102008pdf_chunk21]: Esta fuente de jurisprudencia proporciona un ejemplo de cómo se ha aplicado la agravación de la estafa en un caso real, lo que ayuda a entender la aplicación práctica de la ley.
# 3.[20240825214945csjsp3219714092009pdf_chunk5]: Esta jurisprudencia ofrece otro ejemplo de aplicación de la agravación de la estafa, mostrando cómo se ha interpretado en diferentes contextos judiciales.
# 📋 Agregando fuentes al contexto ...
# 📋 3 fuentes agregadas ...
# 💰 Conversation price: $24375.0945 COP (In: 1143378, Out: 15217, Total token: 1158595)
#    This message: $65.682 COP (In: 2343, Out: 287, Total token: 2630)
# <p>Las causales de agravación de la estafa en Colombia están establecidas en el Código Penal, Ley 599 de 2000. Según el artículo 267, las penas para el delito de estafa se aumentarán de una tercera parte a la mitad cuando la conducta se cometa en las siguientes circunstancias:</p>
#
# <ul>
#     <li>Sobre una cosa cuyo valor sea superior a cien (100) salarios mínimos legales mensuales vigentes, o que, siendo inferior, haya ocasionado grave daño a la víctima, atendida su situación económica.</li>
#     <li>Sobre bienes del Estado.</li>
#     <li>En despoblado o lugar solitario.</li>
#     <li>Sobre objetos de interés científico, histórico, asistencial, educativo, cultural, artístico, sobre bienes de uso público, de utilidad social, o sobre bienes que conforman el patrimonio cultural de la Nación.</li>
# </ul>
#
# <p>Además, un parágrafo adicionado por la Ley 2197 de 2022 establece que la pena será de cuarenta y ocho (48) meses a ciento cuarenta y cuatro (144) meses de prisión cuando se afecte la infraestructura destinada a la seguridad ciudadana, a la administración de justicia, el sistema de transporte público masivo, instalaciones militares o de policía [20240814181609ley599de2000pdf_chunk183].</p>
#
#
# <p>1. Ley 599 de 2000 - Página 103<br>
# 2. CSJ - SP28538(07-10-2008) - Página 20<br>
# 3. CSJ - SP32197(14-09-2009) - Página 6<br>
# </p>
# 🙎‍♂️ User: ¿Cuándo procede la captura en flagrancia?
# 🤖 Generando queries con la pregunta del usuario ...
# 💰 Conversation price: $741.5872949999999 COP (In: 1144725, Out: 15277, Total token: 1160002)
#    This message: $0.9760049999999999 COP (In: 1347, Out: 60, Total token: 1407)
# 🤖 1 búsquedas generadas ...
# Necesito buscar en el Código Penal colombiano, Ley 599 de 2000, para encontrar la definición y condiciones bajo las cuales procede la captura en flagrancia.
# 🔎 Buscando documentos: captura en flagrancia Código Penal Ley 599 de 2000 ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 37 ...
# 📋 Agregando fuentes al contexto ...
# 📋 25 fuentes agregadas ...
# 🤖 Generando nuevas búsquedas con la nueva información ...
# 💰 Conversation price: $750.47958 COP (In: 1158452, Out: 15460, Total token: 1173912)
#    This message: $8.892285 COP (In: 13727, Out: 183, Total token: 13910)
# 🤖 3 búsquedas generadas ...
# Buscando 'captura en flagrancia Código de Procedimiento Penal Ley 906 de 2004': Necesito buscar en el Código de Procedimiento Penal colombiano, Ley 906 de 2004, para encontrar la definición y condiciones bajo las cuales procede la captura en flagrancia, ya que este código regula el procedimiento penal actual.
# 🔎 Buscando documentos: captura en flagrancia Código de Procedimiento Penal Ley 906 de 2004 ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 45 ...
# Buscando 'artículo 301 Código de Procedimiento Penal Ley 906 de 2004': El artículo 301 del Código de Procedimiento Penal es relevante para entender las condiciones específicas de la captura en flagrancia, por lo que es importante buscarlo directamente.
# 🔎 Buscando documentos: artículo 301 Código de Procedimiento Penal Ley 906 de 2004 ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 46 ...
# Buscando 'jurisprudencia sobre captura en flagrancia en Colombia': Buscar jurisprudencia sobre captura en flagrancia en Colombia me ayudará a entender cómo se ha aplicado la ley en casos específicos y qué interpretaciones han hecho los tribunales.
# 🔎 Buscando documentos: jurisprudencia sobre captura en flagrancia en Colombia ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 40 ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 100 pasaron 93 ...
# 📋 Agregando fuentes al contexto ...
# 📋 93 fuentes agregadas ...
# 🤖 Escogiendo las mejores fuentes para responder al usuario ...
# 💰 Conversation price: $779.59983 COP (In: 1204506, Out: 15784, Total token: 1220290)
#    This message: $29.12025 COP (In: 46054, Out: 324, Total token: 46378)
# 1.[20240820085329ley906de2004pdf_chunk166]: Contiene la definición de flagrancia según el artículo 301 de la Ley 906 de 2004, que es crucial para entender cuándo procede la captura en flagrancia.
# 2.[20240820085329ley906de2004pdf_chunk167]: Explica el procedimiento a seguir en caso de captura en flagrancia, según el artículo 302 de la Ley 906 de 2004.
# 3.[20240909114734ccc5672019pdf_chunk115]: Proporciona jurisprudencia sobre el procedimiento y control de legalidad de la captura en flagrancia, lo que ayuda a entender su aplicación práctica.
# 4.[20240827142343ce13410012331000201200065011sentencia20220713162054tclistadotitulados1331242126610912142022pdf_chunk33]: Ofrece un ejemplo de aplicación de la captura en flagrancia y su legalidad, lo que ilustra cómo se lleva a cabo en la práctica.
# 5.[20240815171645ce17001233100020090037401460972020pdf_chunk2]: Describe los requisitos y el procedimiento de captura en flagrancia, proporcionando contexto adicional sobre su aplicación.
# 📋 Agregando fuentes al contexto ...
# 📋 5 fuentes agregadas ...
# 💰 Conversation price: $25758.844500000003 COP (In: 1207836, Out: 16231, Total token: 1224067)
#    This message: $95.7555 COP (In: 3330, Out: 447, Total token: 3777)
# <p>La captura en flagrancia en Colombia procede bajo las siguientes circunstancias, según el artículo 301 de la Ley 906 de 2004:</p>
#
# <ul>
#     <li>Cuando la persona es sorprendida y aprehendida durante la comisión del delito.</li>
#     <li>Cuando la persona es sorprendida o individualizada durante la comisión del delito y aprehendida inmediatamente después por persecución o cuando es señalada por la víctima u otra persona como autor o cómplice del delito inmediatamente después de su perpetración.</li>
#     <li>Cuando la persona es sorprendida y capturada con objetos, instrumentos o huellas que fundadamente indiquen que acaba de cometer un delito o de haber participado en él.</li>
#     <li>Cuando la persona es sorprendida o individualizada en la comisión de un delito en un sitio abierto al público a través de la grabación de un dispositivo de video y aprehendida inmediatamente después.</li>
#     <li>Cuando la persona se encuentra en un vehículo utilizado momentos antes para huir del lugar de la comisión de un delito, salvo que se demuestre que el sujeto no tiene conocimiento de la conducta punible.</li>
# </ul>
#
# <p>El procedimiento en caso de flagrancia, según el artículo 302 de la misma ley, establece que cualquier persona puede capturar a quien sea sorprendido en flagrancia. Si la captura es realizada por una autoridad, debe conducir al aprehendido inmediatamente o a más tardar en el término de la distancia ante la Fiscalía General de la Nación. Si es un particular quien realiza la aprehensión, debe llevar al aprehendido ante cualquier autoridad de policía, que identificará al aprehendido y lo pondrá a disposición de la Fiscalía General de la Nación [20240820085329ley906de2004pdf_chunk166] [20240820085329ley906de2004pdf_chunk167].</p>
#
# <p>La legalidad de la captura debe ser evaluada en una audiencia preliminar ante un juez de control de garantías dentro de las 36 horas siguientes a la aprehensión [20240909114734ccc5672019pdf_chunk115].</p>
#
#
# <p>1. Ley 906 de 2004 - Página 84<br>
# 2. Ley 906 de 2004 - Página 84<br>
# 3. CC - C567-2019 - Página 67<br>
# 4. CE - 13_410012331000201200065011SENTENCIA20220713162054_TCListadoTitulados133124212661091214-2022 - Página 15<br>
# 5. CE-17001-23-31-000-2009-00374-01 (46097)-2020 - Página 1<br>
# </p>

# %%
run_conversation(
    "Dame una sentencia del año 2015 de la corte suprema de justicia que hable sobre el homicidio"
)
# Out:
# 🙎‍♂️ User: Dame una sentencia del año 2015 de la corte suprema de justicia que hable sobre el homicidio
# 🤖 Generando queries con la pregunta del usuario ...
# 💰 Conversation price: $545.8168049999999 COP (In: 839895, Out: 11903, Total token: 851798)
#    This message: $1.03074 COP (In: 1448, Out: 57, Total token: 1505)
# 🤖 1 búsquedas generadas ...
# Necesito buscar una sentencia específica del año 2015 que trate sobre el homicidio, ya que el usuario solicita un documento concreto de la Corte Suprema de Justicia.
# 🔎 Buscando documentos: sentencia homicidio Corte Suprema de Justicia 2015 ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron
...
# 📋 Agregando fuentes al contexto ...
# 📋 50 fuentes agregadas ...
# 🤖 Escogiendo las mejores fuentes para responder al usuario ...
# 💰 Conversation price: $90.00586500000001 COP
#    This message: $64.74105000000002 COP
# 1.[20240823100407cct0502023pdf_chunk48]: Incluye el artículo 49 de la Constitución, que establece el derecho a la salud como fundamental.
# 2.[20240816184829ley1751de2015pdf_chunk0]: Define el derecho a la salud como autónomo e irrenunciable, regulado por la Ley 1751 de 2015.
# 3.[20240817082055ce17001233300020170014801ac2017pdf_chunk15]: Reitera que el derecho a la salud es fundamental y autónomo, vinculado a la dignidad humana.
# 4.[20240823103137cct2642023pdf_chunk22]: Confirma que el derecho a la salud es autónomo e irrenunciable, con acceso a servicios de calidad.
# 5.[20240816184829ley1751de2015pdf_chunk10]: Detalla las obligaciones del Estado en relación con el derecho a la salud, según la Ley 1751.
# 6.[20240816184829ley1751de2015pdf_chunk2]: Establece los principios del derecho a la salud, fundamentales para su aplicación.
# 7.[20240816184829ley1751de2015pdf_chunk1]: Refuerza la naturaleza del derecho a la salud como fundamental y su justiciabilidad.
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 11 pasaron 8 ...
# 📋 Agregando fuentes al contexto ...
# 📋 8 fuentes agregadas ...
# 💰 Conversation price: $404.29136500000004 COP
#    This message: $314.2855 COP
# <p>El derecho a la salud individual está previsto como derecho fundamental autónomo expresamente en la Constitución Política de Colombia. El artículo 49 de la Constitución establece que "se garantiza a todas las personas el acceso a los servicios de promoción, protección y recuperación de la salud" y que corresponde al Estado "organizar, dirigir y reglamentar la prestación de servicios de salud" [20240812195718constitucionpoliticadecolombia1991pdf_chunk17].</p>
#
# <p>Además, la Ley 1751 de 2015, conocida como la Ley Estatutaria de Salud, regula este derecho y lo define como un derecho fundamental autónomo e irrenunciable en lo individual y en lo colectivo. Esta ley establece que el derecho fundamental a la salud comprende el acceso a los servicios de salud de manera oportuna, eficaz y con calidad para la preservación, el mejoramiento y la promoción de la salud [20240816184829ley1751de2015pdf_chunk0].</p>
#
# <p>La Corte Constitucional ha reiterado en su jurisprudencia que el derecho a la salud es un derecho fundamental. En la sentencia T-050 de 2023, la Corte señaló que el artículo 49 de la Constitución reconoce el derecho fundamental a la salud y que este derecho también está consagrado en otros instrumentos internacionales que forman parte del bloque de constitucionalidad [20240823100407cct0502023pdf_chunk48].</p>
#
# <p>En resumen, el derecho a la salud individual está expresamente previsto como un derecho fundamental autónomo en la Constitución Política de Colombia y ha sido desarrollado y regulado por la Ley 1751 de 2015.</p>
#
#
# <p>1. CC - T050-2023 - Página 28<br>
# 2. MINSALUD - Resolución 1411 de 2022 - Página 1<br>
# 3. Constitución Política de Colombia-1991 - Página 20<br>
# 4. Ley 1751 de 2015 - Página 1<br>
# 5. Ley 1751 de 2015 - Página 8<br>
# 6. CC - T264-2023 - Página 11<br>
# 7. Ley 1751 de 2015 - Página 2<br>
# 8. Ley 1751 de 2015 - Página 1<br>
# </p>

# %%
run_conversation(
    "¿El derecho a la salud individual está previsto como derecho fundamental autónomo expresamente en la consitución o su reconocimiento como derecho fundamental se produjo por vía jurisprudencial?"
)
# Out:
# 🙎‍♂️ User: ¿El derecho a la salud individual está previsto como derecho fundamental autónomo expresamente en la consitución o su reconocimiento como derecho fundamental se produjo por vía jurisprudencial?
# 🤖 Generando queries con la pregunta del usuario ...
# 💰 Conversation price: $3.3332999999999995 COP
#    This message: $3.3332999999999995 COP
# 🤖 1 búsquedas generadas ...
# Necesito investigar si el derecho a la salud está explícitamente mencionado en la Constitución de Colombia como un derecho fundamental o si su reconocimiento se ha dado a través de decisiones jurisprudenciales.
# 🔎 Buscando documentos: derecho a la salud Constitución Colombia derecho fundamental jurisprudencia ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 50 ...
# 📋 Agregando fuentes al contexto ...
# 📋 25 fuentes agregadas ...
# ⭐️ Guardando los mejores. De
...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 48 ...
# Buscando 'Ley Estatutaria 1751 de 2015 salud derecho fundamental autónomo': La Ley Estatutaria 1751 de 2015 refuerza el reconocimiento de la salud como un derecho fundamental autónomo, y su análisis puede ofrecer información sobre cómo se ha legislado y protegido este derecho en Colombia.
# 🔎 Buscando documentos: Ley Estatutaria 1751 de 2015 salud derecho fundamental autónomo ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 50 ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 100 pasaron 85 ...
# 📋 Agregando fuentes al contexto ...
# 📋 85 fuentes agregadas ...
# 🤖 Escogiendo las mejores fuentes para responder al usuario ...
# 💰 Conversation price: $510.23229 COP (In: 785590, Out: 11014, Total token: 796604)
#    This message: $27.809684999999995 COP (In: 43539, Out: 420, Total token: 43959)
# 1.[20240814154538cct1262010pdf_chunk11]: Esta fuente es crucial porque menciona directamente la Sentencia T-760 de 2008, que establece que la salud es un derecho fundamental autónomo, y proporciona un contexto sobre su evolución jurisprudencial.
# 2.[20240814184016cct2332011pdf_chunk46]: Esta fuente también se refiere a la Sentencia T-760 de 2008 y explica cómo la Corte ha sistematizado y compilado las reglas sobre el derecho a la salud, lo que es fundamental para entender su carácter autónomo.
# 3.[20240814172036cct9592010pdf_chunk10]: Esta fuente menciona la Sentencia T-859 de 2003, que es relevante porque la Corte ya había comenzado a reconocer la salud como un derecho fundamental autónomo antes de la T-760 de 2008.
# 4.[20240814193117cct6762011pdf_chunk19]: Esta fuente proporciona un resumen de la evolución del derecho a la salud en la jurisprudencia, destacando la importancia de la Sentencia T-760 de 2008 en el reconocimiento de la salud como un derecho fundamental autónomo.
# 5.[20240814114410cct7602008pdf_chunk49]: Esta fuente es esencial porque detalla la Sentencia T-760 de 2008, que es la que reconoce formalmente la salud como un derecho fundamental autónomo, y explica su impacto en la jurisprudencia.
# 📋 Agregando fuentes al contexto ...
# 📋 5 fuentes agregadas ...
# 💰 Conversation price: $16865.575500000003 COP (In: 789093, Out: 11206, Total token: 800299)
#    This message: $83.61950000000002 COP (In: 3503, Out: 192, Total token: 3695)
# <p>La Corte Constitucional de Colombia reconoció por primera vez el derecho a la salud como un derecho fundamental autónomo en la Sentencia T-760 de 2008. Esta sentencia sistematizó y compiló las reglas jurisprudenciales sobre el derecho a la salud, argumentando que este derecho es fundamental de manera autónoma cuando se puede concretar en una garantía subjetiva derivada de las normas que rigen el derecho a la salud. La Corte señaló que el acceso a un servicio de salud contemplado en los planes obligatorios es un derecho fundamental autónomo, y la negación de estos servicios constituye una violación de dicho derecho [20240814154538cct1262010pdf_chunk11] [20240814184016cct2332011pdf_chunk46] [20240814193117cct6762011pdf_chunk19] [20240814114410cct7602008pdf_chunk49].</p>
#
#
# <p>1. CC - T126-2010 - Página 7<br>
# 2. CC - T233-2011 - Página 27<br>
# 3. CC - T959-2010 - Página 8<br>
# 4. CC - T676-2011 - Página 13<br>
# 5. CC - T760-2008 - Página 29<br>
# </p>

# %%
run_conversation("¿Se puede archivar una investigación por légitima defensa?")
# Out:
# 🙎‍♂️ User: ¿Se puede archivar una investigación por légitima defensa?
# 🤖 Generando queries con la pregunta del usuario ...
# 💰 Conversation price: $927.231195 COP (In: 1429273, Out: 19605, Total token: 1448878)
#    This message: $1.07625 COP (In: 1350, Out: 100, Total token: 1450)
# 🤖 2 búsquedas generadas ...
# Necesito entender si la legítima defensa es una causal para archivar una investigación penal, lo cual implica conocer cómo se aplica este concepto en el proceso penal.
# 🔎 Buscando documentos: legítima defensa archivo de investigación penal ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 48 ...
# 📋 Agregando fuentes al contexto ...
# 📋 25 fuentes agregadas ...
# Es importante revisar cómo está definida la legítima defensa en el Código Penal colombiano para entender su aplicación en el contexto de una investigación penal.
# 🔎 Buscando documentos: legítima defensa Código Penal Ley 599 de 2000 ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 46 ...
# 📋 Agregando fuentes al contexto ...
# 📋 25 fuentes agregadas ...
# 🤖 Generando nuevas búsquedas con la nueva información ...
# 💰 Conversation price: $943.6646099999999 COP (In: 1455414, Out: 19750, Total token: 1475164)
#    This message: $16.433415 COP (In: 26141, Out: 145, Total token: 26286)
# 🤖 3 búsquedas generadas ...
# Buscando 'legítima defensa archivo de investigación penal': Necesito entender si la legítima defensa es una causal para archivar una investigación penal, lo cual implica conocer cómo se aplica este concepto en el proceso penal.
# 🔎 Buscando documentos: legítima defensa archivo de investigación penal ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 48 ...
# Buscando 'legítima defensa Código Penal Ley 599 de 2000': Es importante revisar cómo está definida la legítima defensa en el Código Penal colombiano para entender su aplicación en el contexto de una investigación penal.
# 🔎 Buscando documentos: legítima defensa Código Penal Ley 599 de 2000 ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 46 ...
# Buscando 'jurisprudencia archivo de investigación por legítima defensa': Buscar jurisprudencia específica sobre casos donde se haya archivado una investigación por legítima defensa puede proporcionar ejemplos concretos y precedentes legales.
# 🔎 Buscando documentos: jurisprudencia archivo de investigación por legítima defensa ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 39 ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 125 pasaron 66 ...
# 📋 Agregando fuentes al contexto ...
# 📋 66 fuentes agregadas ...
# 🤖 Escogiendo las mejores fuentes para responder al usuario ...
# 💰 Conversation price: $965.6090399999999 COP (In: 1489676, Out: 20105, Total token: 1509781)
#    This message: $21.944429999999997 COP (In: 34262, Out: 355, Total token: 34617)
# 1.[20240813204440ce12680012331000200900675011sentencia20220613163820tclistadotitulados1331318505716123682022pdf_chunk46]: Esta fuente muestra un caso donde se ordenó el archivo de una investigación penal, lo que puede ser relevante para entender cómo se aplica el archivo en casos de legítima defensa.
# 2.[20240820022606cesecciontercera23001233100020000814501163412007pdf_chunk13]: Proporciona un ejemplo de archivo de investigación por legítima defensa, lo que es directamente relevante para la pregunta.
# 3.[20240819085308cesec3exp1998n10754pdf_chunk21]: Explica cómo la legítima defensa puede ser una causal de justificación, lo que es crucial para entender su aplicación en el archivo de investigaciones.
# 4.[20240814181609ley599de2000pdf_chunk11]: Contiene el artículo del Código Penal que define la legítima defensa, esencial para entender su aplicación legal.
# 5.[20240825015013csdjf05001110200020120246401adjunta201604221557172016pdf_chunk4]: Muestra cómo la legítima defensa puede ser utilizada en el contexto de una investigación penal, lo que es relevante para el archivo de casos.
# 📋 Agregando fuentes al contexto ...
# 📋 5 fuentes agregadas ...
# 💰 Conversation price: $31864.523500000003 COP (In: 1493131, Out: 20412, Total token: 1513543)
#    This message: $89.70800000000001 COP (In: 3455, Out: 307, Total token: 3762)
# <p>En Colombia, la legítima defensa puede ser una causal para archivar una investigación penal. La legítima defensa está contemplada como una causal de justificación en el Código Penal, lo que significa que, si se demuestra que una persona actuó en legítima defensa, no habrá lugar a responsabilidad penal. Esto se encuentra en el artículo 32 del Código Penal, que establece las causales de ausencia de responsabilidad, incluyendo la legítima defensa [20240814181609ley599de2000pdf_chunk11].</p>
#
# <p>Existen precedentes en la jurisprudencia colombiana donde se ha ordenado el archivo de investigaciones penales al acreditarse la legítima defensa. Por ejemplo, en un caso del Juzgado 32 de Instrucción Penal Militar, se ordenó archivar las diligencias porque se acreditó que los miembros del ejército actuaron en legítima defensa [20240820022606cesecciontercera23001233100020000814501163412007pdf_chunk13].</p>
#
# <p>Otro ejemplo es un caso donde se concluyó que la legítima defensa era evidente, lo que llevó a cesar el procedimiento en favor de los procesados [20240819085308cesec3exp1998n10754pdf_chunk21].</p>
#
# <p>Por lo tanto, sí es posible archivar una investigación por legítima defensa, siempre y cuando se demuestre que se cumplen los requisitos legales para esta causal de justificación.</p>
#
#
# <p>1. CE - 12_680012331000200900675011SENTENCIA20220613163820_TCListadoTitulados133131850571612368-2022 - Página 26<br>
# 2. CE-SECCION TERCERA-23001-23-31-000-2000-08145-01(16341)-2007 - Página 8<br>
# 3. CE-SEC3-EXP1998-N10754 - Página 15<br>
# 4. Ley 599 de 2000 - Página 9<br>
# 5. CSDJ - F05001110200020120246401ADJUNTA20160422155717-2016 - Página 4<br>
# </p>

# %%
run_conversation("¿Qué dice el artículo 103 del código penal?")
# Out:
# 🙎‍♂️ User: ¿Qué dice el artículo 103 del código penal?
# 🤖 Generando queries con la pregunta del usuario ...
# 💰 Conversation price: $486.4182599999999 COP
#    This message: $3.2699550000000004 COP
# 🤖 1 búsquedas generadas ...
# Necesito buscar el contenido específico del artículo 103 del Código Penal para proporcionar información precisa sobre su contenido y aplicación.
# 🔎 Buscando documentos: artículo 103 Código Penal Ley 599 de 2000 ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 47 ...
# 📋 Agregando fuentes al contexto ...
# 📋 25 fuentes agregadas ...
# 🤖 Generando nuevas búsquedas con la nueva información ...
# 💰 Conversation price: $519.9917249999999 COP
#    This message: $33.573465 COP
# 🤖 3 búsquedas generadas ...
# Buscando 'artículo 103 Código Penal Ley 599 de 2000': Esta búsqueda se centra en obtener el texto exacto del artículo 103 del Código Penal, que establece las penas por homicidio, lo cual es fundamental para responder a la pregunta del usuario.
# 🔎 Buscando documentos: artículo 103 Código Penal Ley 599 de 2000 ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 47 ...
# Buscando 'homicidio Código Penal Colombia': Esta búsqueda ampliará la información sobre el contexto y las implicaciones del homicidio en el Código Penal, permitiendo entender mejor las circunstancias y agravantes que pueden aplicarse según la ley.
# 🔎 Buscando documentos: homicidio Código Penal Colombia ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 27 ...
# Buscando 'penalidades homicidio Colombia': Esta búsqueda se enfocará en las diferentes penalidades y agravantes relacionadas con el homicidio en el contexto colombiano, lo que proporcionará un panorama más completo sobre las consecuencias legales de este delito.
# 🔎 Buscando documentos: penalidades homicidio Colombia ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 35 ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 100 pasaron 65 ...
# 📋 Agregando fuentes al contexto ...
# 📋 65 fuentes agregadas ...
# 🤖 Escogiendo las mejores fuentes para responder al usuario ...
# 💰 Conversation price: $600.5253599999999 COP
#    This message: $80.533635 COP
# 1.[20240917112430ley599de2000pdf_chunk63]: Incluye el texto exacto del artículo 103 del Código Penal, que establece las penas por homicidio.
# 2.[20240917112430ley599de2000pdf_chunk49]: Proporciona contexto sobre el homicidio y menciona la ley 890 de 2004 que aumenta las penas.
# 3.[20240917112430ley599de2000pdf_chunk60]: Ofrece información sobre la responsabilidad civil derivada de conductas punibles, relevante para entender el impacto del homicidio.
# 4.[20240917112430ley599de2000pdf_chunk68]: Menciona el homicidio preterintencional, lo que ayuda a entender diferentes tipos de homicidio en el Código Penal.
# 5.[20240917112430ley599de2000pdf_chunk105]: Incluye información sobre homicidio por piedad, ampliando la comprensión de las circunstancias que rodean el homicidio.
# 📋 Agregando fuentes al contexto ...
# 📋 4 fuentes agregadas ...
# 💰 Conversation price: $787.8338599999998 COP
#    This message: $187.3085 COP
# <p>El artículo 103 del Código Penal colombiano, contenido en la Ley 599 de 2000, establece lo siguiente:</p>
#
# <p><strong>Artículo 103. Homicidio.</strong> El que matare a otro, incurrirá en prisión de doscientos ocho (208) a cuatrocientos cincuenta (450) meses.</p>
#
# <p>Nota: Las penas fueron aumentadas por el artículo 14 de la Ley 890 de 2004, vigente a partir del 1° de enero de 2005 [20240917112430ley599de2000pdf_chunk63].</p>
#
#
# <p>1. Ley 599 de 2000 - Página 72<br>
# 2. Ley 599 de 2000 - Página 55<br>
# 3. Ley 599 de 2000 - Página 68<br>
# 4. Ley 599 de 2000 - Página 77<br>
# </p>

# %%
run_conversation("¿Cuándo se consuma el hurto?")
# Out:
# 🙎‍♂️ User: ¿Cuándo se consuma el hurto?
# 🤖 Generando queries con la pregunta del usuario ...
# 💰 Conversation price: $0.9569399999999999 COP
#    This message: $0.9569399999999999 COP
# 🤖 1 búsquedas generadas ...
# Es necesario entender el momento en que se considera que el delito de hurto se ha consumado, para poder aplicar correctamente las normas penales y determinar las consecuencias legales del acto.
# 🔎 Buscando documentos: ¿cuándo se consuma el hurto? ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 36 ...
# 📋 Agregando fuentes al contexto ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 15 pasaron 15 ...
# 📋 15 fuentes agregadas ...
# ⭐️ Guardando los mejores. De 15 pasaron 5 ...
# 🤖 Generando nuevas búsquedas con la nueva información ...
# 💰 Conversation price: $6.92121 COP
#    This message: $5.96427 COP
# 🤖 3 búsquedas generadas ...
# Buscando '¿Cuándo se considera consumado el hurto en el derecho penal colombiano?': Esta búsqueda se centra en la definición y el momento específico en que se considera que el hurto se ha consumado, lo cual es fundamental para entender la aplicación de la ley penal en Colombia.
# 🔎 Buscando documentos: ¿Cuándo se considera consumado el hurto en el derecho penal colombiano? ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 30 ...
# ⭐️ Guardando los mejores. De 15 pasaron 5 ...
# Buscando 'teoría de la disponibilidad en el hurto derecho penal colombiano': La teoría de la disponibilidad es clave para entender cómo se determina el momento consumativo del hurto, por lo que buscar información específica sobre esta teoría ayudará a profundizar en el concepto.
# 🔎 Buscando documentos: teoría de la disponibilidad en el hurto derecho penal colombiano ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 14 ...
# ⭐️ Guardando los mejores. De 14 pasaron 1 ...
# Buscando 'artículo 239 Código Penal Ley 599 de 2000 sobre el hurto': Consultar el artículo específico del Código Penal que define el hurto y sus implicaciones legales proporcionará un marco normativo claro y preciso sobre el tema.
# 🔎 Buscando documentos: artículo 239 Código Penal Ley 599 de 2000 sobre el hurto ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 44 ...
# ⭐️ Guardando los mejores. De 15 pasaron 5 ...
# 📋 Agregando fuentes al contexto ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 59 pasaron 52 ...
# 📋 52 fuentes agregadas ...
# 🤖 Escogiendo las mejores fuentes para responder al usuario ...
# 💰 Conversation price: $24.71562 COP
#    This message: $17.79441 COP
# 1.[20240813150354universidadexternadoleccionesdederechopenalparteespecialvol12011pdf_chunk1097]: Define el momento consumativo del hurto según la teoría de la disponibilidad.
# 2.[20240821001640pgnhurtomomentoconsumativopdf_chunk18]: Explica el momento consumativo del hurto y la pérdida de protección de la víctima.
# 3.[20240824103421csjsp2030416122002pdf_chunk4]: Cita jurisprudencia que establece el momento consumativo del hurto.
# 4.[20240825010449csjsp2462506042006pdf_chunk3]: Reitera que el hurto se consuma cuando el delincuente asume el poder sobre el bien.
# 5.[20240825040459csjsentencia2496726092007pdf_chunk3]: Aporta la teoría de la disponibilidad y su relación con el hurto consumado.
# 6.[20240826145236csjsp3599829062011pdf_chunk10]: Define el hurto como un delito de resultado, enfatizando la disponibilidad.
# 7.[20240917112430ley599de2000pdf_chunk144]: Proporciona el texto del artículo 239 del Código Penal sobre el hurto.
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 16 pasaron 11 ...
# 📋 Agregando fuentes al contexto ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 11 pasaron 11 ...
# 📋 11 fuentes agregadas ...
# 💰 Conversation price: $180.88462 COP
#    This message: $156.169 COP
# <p>El delito de hurto se consuma cuando el autor realiza el desplazamiento físico de la cosa, trasladándola desde la esfera de dominio del dueño a la suya. Esto significa que el resultado del delito se produce cuando la cosa se incorpora a la propia esfera de dominio del autor, es decir, cuando ha logrado, aunque sea por un breve instante, la disponibilidad sobre la cosa sustraída. En este momento se conjugan, al menos potencialmente, la pérdida de poder por parte del dueño o poseedor y la adquisición del mismo por parte del autor, sin que se exija la efectiva disposición del objeto material [20240814213538tsdjmanizalesap20148083402pdf_chunk33].</p>
#
# <p>La Corte Suprema de Justicia ha sostenido que el delito de hurto se consuma en el momento en que la cosa se extrae de la esfera patrimonial o de custodia de quien antes la tenía. Esto implica que el momento consumativo del hurto es cuando el delincuente asume el poder sobre el bien y la víctima pierde la factibilidad de protección o de dominio sobre el mismo debido al apoderamiento inconsulto [20240824103421csjsp2030416122002pdf_chunk4].</p>
#
# <p>En resumen, el hurto se consuma cuando el sujeto activo saca la cosa codiciada de la esfera de poder del sujeto pasivo y la lleva a la suya, logrando así la disponibilidad sobre la cosa sustraída, aunque sea por un breve instante [20240820224441tsdjmanizalessp20160154701hpdf_chunk16].</p>
#
#
# <p>1. UNIVERSIDAD EXTERNADO - Lecciones de Derecho penal - parte especial vol 1 -2011 - Página 949<br>
# 2. PGN - HURTO - Momento consumativo - Página 13<br>
# 3. TSDJ Manizales - AP2014-80834-02- - Página 24<br>
# 4. TSDJ Manizales - SP2016-01547-01 H - Página 15<br>
# 5. UNIVERSIDAD EXTERNADO - Lecciones de Derecho penal - parte especial vol 1 -2011 - Página 948<br>
# 6. Ley 599 de 2000 - Página 164<br>
# 7. CSJ - SP20304(16-12-2002) - Página 5<br>
# 8. CSJ - SP24625(06-04-2006) - Página 4<br>
# 9. CSJ - Sentencia 24967(26-09-2007) - Página 4<br>
# 10. CSJ - SP35998(29-06-2011) - Página 11<br>
# 11. Ley 599 de 2000 - Página 165<br>
# </p>

# %%
run_conversation("¿Qué dice el artículo 103 del Código Penal?")
# Out:
# 🙎‍♂️ User: ¿Qué dice el artículo 103 del Código Penal?
# 🤖 Generando queries con la pregunta del usuario ...
# 💰 Conversation price: $166.18652999999998 COP (In: 255366, Out: 3714, Total token: 259080)
#    This message: $1.004295 COP (In: 1437, Out: 49, Total token: 1486)
# 🤖 1 búsquedas generadas ...
# Necesito buscar el contenido específico del artículo 103 del Código Penal para proporcionar la información exacta que se requiere.
# 🔎 Buscando documentos: artículo 103 Código Penal Ley 599 de 2000 ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 47 ...
# 📋 Agregando fuentes al contexto ...
# 📋 25 fuentes agregadas ...
# 🤖 Generando nuevas búsquedas con la nueva información ...
# 💰 Conversation price: $175.059135 COP (In: 269089, Out: 3890, Total token: 272979)
#    This message: $8.872605 COP (In: 13723, Out: 176, Total token: 13899)
# 🤖 3 búsquedas generadas ...
# Buscando 'artículo 103 Código Penal Ley 599 de 2000': Esta búsqueda es necesaria para obtener el texto exacto del artículo 103 del Código Penal, que establece las penas por homicidio, lo cual es fundamental para responder a la pregunta del usuario.
# 🔎 Buscando documentos: artículo 103 Código Penal Ley 599 de 2000 ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 47 ...
# Buscando 'homicidio Código Penal Ley 599 de 2000': Esta búsqueda permitirá encontrar información adicional sobre el contexto y las implicaciones del delito de homicidio según el Código Penal, lo que puede enriquecer la respuesta al usuario.
# 🔎 Buscando documentos: homicidio Código Penal Ley 599 de 2000 ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 49 ...
# Buscando 'penalidades homicidio Código Penal Ley 599 de 2000': Esta búsqueda se centra en las penalidades específicas relacionadas con el homicidio, lo que ayudará a detallar las consecuencias legales y las variaciones en las penas, proporcionando una respuesta más completa.
# 🔎 Buscando documentos: penalidades homicidio Código Penal Ley 599 de 2000 ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 49 ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 100 pasaron 40 ...
# 📋 Agregando fuentes al contexto ...
# 📋 40 fuentes agregadas ...
# 🤖 Escogiendo las mejores fuentes para responder al usuario ...
# 💰 Conversation price: $189.081135 COP (In: 290569, Out: 4220, Total token: 294789)
#    This message: $14.022 COP (In: 21480, Out: 330, Total token: 21810)
# 1.[20240917112430ley599de2000pdf_chunk63]: Este fragmento contiene el texto exacto del artículo 103 del Código Penal, que es fundamental para responder a la consulta del usuario.
# 2.[20240816115745ce20001233100020110026501476082020pdf_chunk50]: Esta fuente proporciona un contexto jurisprudencial sobre el artículo 103, mencionando su contenido y las penas asociadas, lo que ayuda a entender su aplicación.
# 3.[20240917112430ley599de2000pdf_chunk291]: Este fragmento también menciona el artículo 103 y su relación con las penas aumentadas por la Ley 890 de 2004, lo que es relevante para entender las modificaciones a la pena original.
# 4.[20240917112430ley599de2000pdf_chunk14]: Este fragmento proporciona información sobre las circunstancias de agravación punitiva relacionadas con el homicidio, lo que complementa la información del artículo 103.
# 5.[20240917112430ley599de2000pdf_chunk60]: Este fragmento menciona las penas por homicidio culposo, lo que puede ser útil para contrastar con las penas del homicidio doloso establecidas en el artículo 103.
# 📋 Agregando fuentes al contexto ...
# 📋 4 fuentes agregadas ...
# 💰 Conversation price: $6286.161000000001 COP (In: 293517, Out: 4375, Total token: 297892)
#    This message: $69.9665 COP (In: 2948, Out: 155, Total token: 3103)
# <p>El artículo 103 del Código Penal colombiano, contenido en la Ley 599 de 2000, establece lo siguiente:</p>
#
# <p><strong>Artículo 103. Homicidio.</strong> El que matare a otro, incurrirá en prisión de doscientos ocho (208) a cuatrocientos cincuenta (450) meses.</p>
#
# <p><em>Nota:</em> Las penas fueron aumentadas por el artículo 14 de la Ley 890 de 2004, con vigencia a partir del 1° de enero de 2005.</p>
#
# <p>[Fuente: Ley 599 de 2000, página 72] [20240917112430ley599de2000pdf_chunk63]</p>
#
#
# <p>1. Ley 599 de 2000 - Página 72<br>
# 2. CE-20001-23-31-000-2011-00265-01(47608)-2020 - Página 24<br>
# 3. Ley 599 de 2000 - Página 323<br>
# 5. Ley 599 de 2000 - Página 68<br>
# </p>

# %%
run_conversation("Dame el artículo 103 del código penal")
# Out:
# 🙎‍♂️ User: Dame el artículo 103 del código penal
# 🤖 Generando queries con la pregunta del usuario ...
# 💰 Conversation price: $1.00491 COP (In: 1434, Out: 50, Total token: 1484)
#    This message: $1.00491 COP (In: 1434, Out: 50, Total token: 1484)
# 🤖 1 búsquedas generadas ...
# Necesito buscar el contenido específico del artículo 103 del Código Penal para proporcionar la información exacta que el usuario solicita.
# 🔎 Buscando documentos: artículo 103 Código Penal Ley 599 de 2000 ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 47 ...
# 📋 Agregando fuentes al contexto ...
# 📋 25 fuentes agregadas ...
# 🤖 Generando nuevas búsquedas con la nueva información ...
# 💰 Conversation price: $9.89904 COP (In: 15152, Out: 236, Total token: 15388)
#    This message: $8.894129999999999 COP (In: 13718, Out: 186, Total token: 13904)
# 🤖 3 búsquedas generadas ...
# Buscando 'artículo 103 Código Penal Ley 599 de 2000': Esta búsqueda es necesaria para obtener el texto exacto del artículo 103 del Código Penal, que trata sobre el homicidio y sus penas, lo cual es la información específica que el usuario solicita.
# 🔎 Buscando documentos: artículo 103 Código Penal Ley 599 de 2000 ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 47 ...
# Buscando 'homicidio Código Penal Ley 599 de 2000': Esta búsqueda ampliará la información sobre el contexto del homicidio en el Código Penal, incluyendo posibles artículos relacionados que puedan ofrecer una comprensión más completa de las disposiciones legales sobre este delito.
# 🔎 Buscando documentos: homicidio Código Penal Ley 599 de 2000 ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 49 ...
# Buscando 'penalidad homicidio artículo 103 Código Penal': Esta búsqueda se centrará en las penas específicas asociadas al homicidio según el artículo 103, lo que permitirá al usuario entender no solo el texto del artículo, sino también las implicaciones legales y las circunstancias que pueden afectar la pena.
# 🔎 Buscando documentos: penalidad homicidio artículo 103 Código Penal ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 23 ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 98 pasaron 59 ...
# 📋 Agregando fuentes al contexto ...
# 📋 59 fuentes agregadas ...
# 🤖 Escogiendo las mejores fuentes para responder al usuario ...
# 💰 Conversation price: $29.706345 COP (In: 46011, Out: 573, Total token: 46584)
#    This message: $19.807304999999996 COP (In: 30859, Out: 337, Total token: 31196)
# 1.[20240820101403tsdjmanizalessp20170009200pdf_chunk18]: Esta fuente proporciona el texto exacto del artículo 103 del Código Penal, que es lo que el usuario solicitó.
# 2.[20240823235143csjsp1931116042002pdf_chunk10]: Esta fuente también menciona el artículo 103 del Código Penal y su relación con el homicidio, lo que ayuda a contextualizar la información.
# 3.[20240816115745ce20001233100020110026501476082020pdf_chunk50]: Esta fuente incluye una referencia a la pena establecida en el artículo 103 del Código Penal, lo que es relevante para entender las implicaciones legales del homicidio.
# 4.[20240816182015tnemgjdenunciaentremedicosagosto2020pdf_chunk44]: Esta fuente menciona el artículo 103 y proporciona contexto sobre el homicidio y su clasificación, lo que es útil para una comprensión más amplia.
# 5.[20240823072132csdjf11001010200020130151800adjunta201309191622372013pdf_chunk46]: Esta fuente ofrece una interpretación del artículo 103 y su aplicación en el contexto del homicidio, lo que es importante para entender su aplicación práctica.
# 📋 Agregando fuentes al contexto ...
# 📋 3 fuentes agregadas ...
# 💰 Conversation price: $1037.6485 COP (In: 48463, Out: 718, Total token: 49181)
#    This message: $59.18350000000001 COP (In: 2452, Out: 145, Total token: 2597)
# <p>El artículo 103 del Código Penal colombiano establece lo siguiente:</p>
#
# <p><strong>ARTÍCULO 103. HOMICIDIO.</strong> <em><Penas aumentadas por el artículo 14 de la Ley 890 de 2004, a partir del 1o. de enero de 2005. El texto con las penas aumentadas es el siguiente:></em></p>
#
# <p>El que matare a otro, incurrirá en prisión de doscientos ocho (208) a cuatrocientos cincuenta (450) meses.</p>
#
# <p>[20240820101403tsdjmanizalessp20170009200pdf_chunk18]</p>
#
#
# <p>1. TSDJ Manizales - SP2017-00092-00 - Página 18<br>
# 2. CSJ - SP19311(16-04-2002) - Página 10<br>
# 3. CE-20001-23-31-000-2011-00265-01(47608)-2020 - Página 24<br>
# </p>

# %%
run_conversation("¿Qué dice el artículo 103 del código penal?")
# Out:
# 🙎‍♂️ User: ¿Qué dice el artículo 103 del código penal?
# 🤖 Generando queries con la pregunta del usuario ...
# 💰 Conversation price: $3.2422799999999996 COP
#    This message: $3.2422799999999996 COP
# 🤖 1 búsquedas generadas ...
# Necesito buscar el contenido específico del artículo 103 del Código Penal para proporcionar la información exacta que se requiere sobre este artículo.
# 🔎 Buscando documentos: artículo 103 Código Penal Ley 599 de 2000 ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 47 ...
# 📋 Agregando fuentes al contexto ...
# 📋 25 fuentes agregadas ...
# 🤖 Generando nuevas búsquedas con la nueva información ...
# 💰 Conversation price: $36.80529 COP
#    This message: $33.56301 COP
# 🤖 3 búsquedas generadas ...
# Buscando 'artículo 103 Código Penal Ley 599 de 2000': Esta búsqueda es fundamental porque el artículo 103 del Código Penal establece la pena por homicidio, que es el tema central de la pregunta del usuario. Obtener el texto exacto de este artículo permitirá responder de manera precisa.
# 🔎 Buscando documentos: artículo 103 Código Penal Ley 599 de 2000 ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 47 ...
# Buscando 'homicidio Código Penal Ley 599 de 2000': Realizar esta búsqueda permitirá obtener información adicional sobre el contexto y las implicaciones del homicidio según el Código Penal, así como posibles artículos relacionados que puedan enriquecer la respuesta.
# 🔎 Buscando documentos: homicidio Código Penal Ley 599 de 2000 ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 49 ...
# Buscando 'penalidad homicidio Colombia': Esta búsqueda se centra en la penalidad específica relacionada con el homicidio en Colombia, lo que puede proporcionar información sobre las penas y circunstancias agravantes o atenuantes que se aplican, complementando así la información del artículo 103.
# 🔎 Buscando documentos: penalidad homicidio Colombia ...
# 📋 Agarrando todos los resultados ...
# 📋 Formateando resultados ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 50 pasaron 36 ...
# 🧹 Eliminando fuentes irrelevantes o duplicadas ...
# 🧹 Docs filtrados. De 100 pasaron 63 ...
# 📋 Agregando fuentes al contexto ...
# 📋 63 fuentes agregadas ...
# 🤖 Escogiendo las mejores fuentes para responder al usuario ...
# 💰 Conversation price: $116.09478 COP
#    This message: $79.28949 COP
# 1.[20240917112430ley599de2000pdf_chunk63]: Incluye el texto exacto del artículo 103 del Código Penal, que define el homicidio y su pena.
# 2.[20240816115745ce20001233100020110026501476082020pdf_chunk50]: Proporciona el texto del artículo 103 y menciona la pena correspondiente, útil para entender su aplicación.
# 3.[20240917112430ley599de2000pdf_chunk49]: Contiene información sobre el contexto del homicidio y menciona la ley 890 de 2004 que aumenta las penas.
# 4.[20240917112430ley599de2000pdf_chunk0]: Es el documento base del Código Penal, esencial para entender el artículo 103 en su contexto.
# 5.[20240917112430ley599de2000pdf_chunk5]: Ofrece información sobre la legalidad y principios del derecho penal, relevante para el artículo 103.
# 📋 Agregando fuentes al contexto ...
# 📋 5 fuentes agregadas ...
# 💰 Conversation price: $337.24878 COP
#    This message: $221.154 COP
# <p>El artículo 103 del Código Penal colombiano, contenido en la Ley 599 de 2000, establece lo siguiente:</p>
#
# <p><strong>Artículo 103. Homicidio.</strong> El que matare a otro, incurrirá en prisión de doscientos ocho (208) a cuatrocientos cincuenta (450) meses.</p>
#
# <p>Nota: Las penas fueron aumentadas por el artículo 14 de la Ley 890 de 2004, con vigencia a partir del 1° de enero de 2005.</p>
#
# <p>Además, el artículo 103A introduce circunstancias de agravación punitiva cuando el homicidio recae en un niño, niña o adolescente, aumentando la pena a un rango de 480 a 600 meses de prisión si la víctima es una persona menor de edad [20240917112430ley599de2000pdf_chunk63] [20240816115745ce20001233100020110026501476082020pdf_chunk50].</p>
#
#
# <p>1. Ley 599 de 2000 - Página 72<br>
# 2. CE-20001-23-31-000-2011-00265-01(47608)-2020 - Página 24<br>
# 3. Ley 599 de 2000 - Página 55<br>
# 4. Ley 599 de 2000 - Página 1<br>
# 5. Ley 599 de 2000 - Página 6<br>
# </p>
